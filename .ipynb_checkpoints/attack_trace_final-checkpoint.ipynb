# %%
import os
from pathlib import Path
import copy
import numpy as np
import torch

from pcdet.config import cfg, cfg_from_yaml_file
from pcdet.models import build_network, load_data_to_gpu
from pcdet.datasets import build_dataloader
from pcdet.utils import common_utils
import random

import math
from dataclasses import dataclass
from typing import Dict, List, Optional, Tuple

import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.io as pio

import helpers
import importlib

from collections import defaultdict

importlib.reload(helpers)
# Out:
# /storage/home/hcoda1/9/spanse30/.conda/envs/mmlab/lib/python3.9/site-packages/spconv/pytorch/functional.py:47: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   _TORCH_CUSTOM_FWD = amp.custom_fwd(cast_inputs=torch.float16)
# /storage/home/hcoda1/9/spanse30/.conda/envs/mmlab/lib/python3.9/site-packages/spconv/pytorch/functional.py:97: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# /storage/home/hcoda1/9/spanse30/.conda/envs/mmlab/lib/python3.9/site-packages/spconv/pytorch/functional.py:163: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# /storage/home/hcoda1/9/spanse30/.conda/envs/mmlab/lib/python3.9/site-packages/spconv/pytorch/functional.py:243: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# /storage/home/hcoda1/9/spanse30/.conda/envs/mmlab/lib/python3.9/site-packages/spconv/pytorch/functional.py:332: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# /storage/home/hcoda1/9/spanse30/.conda/envs/mmlab/lib/python3.9/site-packages/spconv/pytorch/functional.py:369: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# /storage/home/hcoda1/9/spanse30/.conda/envs/mmlab/lib/python3.9/site-packages/spconv/pytorch/functional.py:389: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# /storage/home/hcoda1/9/spanse30/.conda/envs/mmlab/lib/python3.9/site-packages/spconv/pytorch/functional.py:412: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# /storage/project/r-gchou3-0/spanse30/OpenPCDet/pcdet/utils/loss_utils.py:152: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float16)
# <module 'helpers' from '/storage/project/r-gchou3-0/spanse30/OpenPCDet/helpers.py'>

# %%
CFG_FILE = 'tools/cfgs/waymo_models/centerpoint.yaml' 
CKPT = 'output/cfgs/custom_models/centerpoint_singleframe_waymo/default/ckpt/checkpoint_epoch_30.pth'  # <- put your ckpt here

cfg_from_yaml_file(CFG_FILE, cfg)
cfg.TAG = Path(CFG_FILE).stem
cfg.EXP_GROUP_PATH = 'centerpoint_waymo_demo'

logger = common_utils.create_logger()
logger.info(f'Loaded cfg from {CFG_FILE}')

dataset, test_loader, _ = build_dataloader(
    dataset_cfg=cfg.DATA_CONFIG,
    class_names=cfg.CLASS_NAMES,
    batch_size=1,
    dist=False,
    workers=4,
    logger=logger,
    training=False
)

len_test = len(dataset)
logger.info(f'Test set length: {len_test}')
model = build_network(
    model_cfg=cfg.MODEL,
    num_class=len(cfg.CLASS_NAMES),
    dataset=dataset
)

logger.info(f'Loading checkpoint from: {CKPT}')
model.load_params_from_file(filename=CKPT, logger=logger, to_cpu=False)
model.cuda()
model.eval()

data_iter = iter(test_loader)
batch_dict = next(data_iter)

load_data_to_gpu(batch_dict)

# Sanity check shapes
print('points:', batch_dict['points'].shape)         # [N, 5] -> [batch_idx, x, y, z, i]
print('voxels:', batch_dict['voxels'].shape)         # [V, T, C]
print('voxel_coords:', batch_dict['voxel_coords'].shape)  # [V, 4] -> [b, z, y, x]
print('voxel_num_points:', batch_dict['voxel_num_points'].shape)  # [V]
# Out:
# 2026-01-31 16:37:14,263   INFO  Loaded cfg from tools/cfgs/waymo_models/centerpoint.yaml
# 2026-01-31 16:37:14,299   INFO  Loading Waymo dataset
# 2026-01-31 16:37:35,772   INFO  Total skipped info 0
# 2026-01-31 16:37:35,773   INFO  Total samples for Waymo dataset: 38597
# 2026-01-31 16:37:35,774   INFO  Test set length: 38597
# 2026-01-31 16:37:37,191   INFO  Loading checkpoint from: output/cfgs/custom_models/centerpoint_singleframe_waymo/default/ckpt/checkpoint_epoch_30.pth
# 2026-01-31 16:37:37,235   INFO  ==> Loading parameters from checkpoint output/cfgs/custom_models/centerpoint_singleframe_waymo/default/ckpt/checkpoint_epoch_30.pth to GPU
# /storage/project/r-gchou3-0/spanse30/OpenPCDet/pcdet/models/detectors/detector3d_template.py:367: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, map_location=loc_type)
# 2026-01-31 16:37:37,588   INFO  ==> Checkpoint trained from version: pcdet+0.6.0+233f849
# 2026-01-31 16:37:37,617   INFO  ==> Done (loaded 279/279)
# points: torch.Size([126501, 6])
# voxels: torch.Size([75604, 5, 5])
# voxel_coords: torch.Size([75604, 4])
# voxel_num_points: torch.Size([75604])

# %%
# traces = []
# for i in range(0, 100):
#     boxes = dataset[i]['gt_boxes']
#     points = dataset[i]['points']
#     mask = boxes[:, 7]==1
#     boxes_car = boxes[mask]

#     extracted_traces = []
#     for box in boxes_car:
#         cx, cy, cz = box[0], box[1], box[2]
#         dx, dy, dz = box[3], box[4], box[5]
#         heading = box[6]

#         #put box center at origin
#         shifted_points = points[:, :3] - np.array([cx, cy, cz])

#         #rotate points to align with the box's local axes
#         #rotate by -heading to undo boxes rotation
#         cos_a = np.cos(-heading)
#         sin_a = np.sin(-heading)
#         R = np.array([
#             [cos_a, -sin_a, 0],
#             [sin_a,  cos_a, 0],
#             [0,      0,     1]])
#         local_points = shifted_points@R.T
#         inside_mask = (
#             (np.abs(local_points[:, 0]) <= dx / 2) &
#             (np.abs(local_points[:, 1]) <= dy / 2) &
#             (np.abs(local_points[:, 2]) <= dz / 2)
#         )
#         points_inside = points[inside_mask]
#         if len(points_inside) > 0:
#             extracted_traces.append({
#                 'frame': i,
#                 'box': box,
#                 'points': points_inside,
#                 'num_points': len(points_inside)
#             })
#     # print(f"=============frame {i}============")
#     for trace in extracted_traces:
#     # print(trace['points'])
#         # print(trace['num_points'], np.linalg.norm(trace['box'][:3]))
#         if(trace['num_points'] <= 100): traces.append(trace)

# # for i, trace in enumerate(traces):
# #     print(i, trace['frame'], trace['num_points'])
traces_smaller = []

flag = 0
for i in range(0, 100):
    boxes = dataset[i]['gt_boxes']
    points = dataset[i]['points']
    mask = boxes[:, 7]==1
    boxes_car = boxes[mask]

    extracted_traces = []
    for box in boxes_car:
        cx, cy, cz = box[0], box[1], box[2]
        dx, dy, dz = box[3], box[4], box[5]
        heading = box[6]

        #put box center at origin
        shifted_points = points[:, :3] - np.array([cx, cy, cz])

        #rotate points to align with the box's local axes
        #rotate by -heading to undo boxes rotation
        cos_a = np.cos(-heading)
        sin_a = np.sin(-heading)
        R = np.array([
            [cos_a, -sin_a, 0],
            [sin_a,  cos_a, 0],
            [0,      0,     1]])
        local_points = shifted_points@R.T
        inside_mask = (
            (np.abs(local_points[:, 0]) <= dx / 2) &
            (np.abs(local_points[:, 1]) <= dy / 2) &
            (np.abs(local_points[:, 2]) <= dz / 2)
        )
        points_inside = points[inside_mask]
        if len(points_inside) > 0:
            extracted_traces.append({
                'frame': i,
                'box': box,
                'points': points_inside,
                'num_points': len(points_inside)
            })
    # print(f"=============frame {i}============")
    for trace in extracted_traces:
    # print(trace['points'])
        # print(trace['num_points'], np.linalg.norm(trace['box'][:3]))
        if(trace['num_points'] <= 100 and trace['num_points'] >=30): traces_smaller.append(trace)
        if(len(traces_smaller) == 100):
            flag = 1
            break
    if(flag): break

    # if(len(traces) == 100): break
    
traces_bigger = []
flag = 0
for i in range(0, 100):
    boxes = dataset[i]['gt_boxes']
    points = dataset[i]['points']
    mask = boxes[:, 7]==1
    boxes_car = boxes[mask]

    extracted_traces = []
    for box in boxes_car:
        cx, cy, cz = box[0], box[1], box[2]
        dx, dy, dz = box[3], box[4], box[5]
        heading = box[6]

        #put box center at origin
        shifted_points = points[:, :3] - np.array([cx, cy, cz])

        #rotate points to align with the box's local axes
        #rotate by -heading to undo boxes rotation
        cos_a = np.cos(-heading)
        sin_a = np.sin(-heading)
        R = np.array([
            [cos_a, -sin_a, 0],
            [sin_a,  cos_a, 0],
            [0,      0,     1]])
        local_points = shifted_points@R.T
        inside_mask = (
            (np.abs(local_points[:, 0]) <= dx / 2) &
            (np.abs(local_points[:, 1]) <= dy / 2) &
            (np.abs(local_points[:, 2]) <= dz / 2)
        )
        points_inside = points[inside_mask]
        if len(points_inside) > 0:
            extracted_traces.append({
                'frame': i,
                'box': box,
                'points': points_inside,
                'num_points': len(points_inside)
            })
    # print(f"=============frame {i}============")
    for trace in extracted_traces:
    # print(trace['points'])
        # print(trace['num_points'], np.linalg.norm(trace['box'][:3]))
        if(trace['num_points'] <= 200 and trace['num_points'] >=100): traces_bigger.append(trace)
        if(len(traces_bigger) == 100):
            flag = 1
            break
    if(flag): break

# for i, trace in enumerate(traces):
#     print(i, trace['frame'], trace['num_points'])

# %%
importlib.reload(helpers)
# Out:
# <module 'helpers' from '/storage/project/r-gchou3-0/spanse30/OpenPCDet/helpers.py'>

# %%
# TODO: ONLY ROTATE IF ORIGINAL TRACE POSITION IS BEHIND EGO
frame = 50
dict_clean = dataset[frame]
dict_clean = helpers.inject_gt_names(dict_clean, dataset.class_names)
dict_clean = dataset.prepare_data(dict_clean)
dict_clean['batch_size'] = 1
load_data_to_gpu(dict_clean)
batch_clean = helpers.convert_to_batch(dict_clean)
model.eval()
with torch.no_grad():
    pred_clean, _ = model.forward(batch_clean)

# %%
len(traces)
# Out:
# 348

# %%
frame = 50
spoof_data_smaller= []
spoof_data_bigger= []
failed_attempts_smaller = []
failed_attempts_bigger = []

# %%
for i, trace in enumerate(traces_smaller):    
    selected_trace = trace
    centered_points_trace = selected_trace['points'][:, :2] - selected_trace['box'][:2]
    position = np.array([15, -3])

    angle = 0
    if(selected_trace['box'][0]<0):
        # print("rear object")
        angle = np.pi

    c = np.cos(angle)
    s = np.sin(angle)
    R = np.array([[c, -s],
                  [s, c]])


    rotated_trace = centered_points_trace @ R.T
    front_near_trace_planar = rotated_trace + position
    front_near_trace = np.concatenate([front_near_trace_planar, selected_trace['points'][:, 2].reshape(-1, 1)], axis = 1)

    # helpers.plot_trace(front_near_trace)

    importlib.reload(helpers)
    r_trace, theta_trace, phi_trace = helpers.cart_2_spherical(front_near_trace)
    scene_points = dataset[frame]['points'][:, :3]
    r_scene, theta_scene, phi_scene = helpers.cart_2_spherical(scene_points)

    trace_spherical = np.concatenate([r_trace.reshape(-1, 1), theta_trace.reshape(-1, 1), phi_trace.reshape(-1, 1)], axis = 1)
    scene_spherical = np.concatenate([r_scene.reshape(-1, 1), theta_scene.reshape(-1, 1), phi_scene.reshape(-1, 1)], axis = 1)

    azimuths = np.deg2rad(np.arange(0, 360.1, np.deg2rad(0.1358)))
    elevations = np.load('waymo_top_lidar_inclinations.npy')


    Grid = defaultdict(list)
    dtheta = np.deg2rad(0.1358)
    for idx, (r, theta, phi) in enumerate(scene_spherical):
        az = theta % (2*np.pi)
        az_idx = int(np.floor(az/dtheta))
        beam_idx = np.argmin(np.abs(elevations-phi))
        Grid[(az_idx, beam_idx)].append((r, idx))
    for key in Grid:
        Grid[key].sort(key=lambda x: x[0])  # sort by range


    remove_spoof = []
    remove_scene = []
    for idx, (r, theta, phi) in enumerate(trace_spherical):
        az = theta % (2*np.pi)
        az_idx = int(np.floor(az/dtheta))
        beam_idx = np.argmin(np.abs(elevations-phi))
        returns = Grid[(az_idx, beam_idx)]
        if(len(returns) == 0):
            continue
        else:
            # spoof point is behind first real return, remove it
            if returns[0][0] < r:
                # print(round(azimuths[az_idx], 4), round(elevations[beam_idx], 4), round(r, 4), returns[0][0], returns[0][1])
                #ranges are already sorted in ascending order
                remove_spoof.append(idx)
            #spoof is front of all real returns
            elif r < returns[0][0]:
                for element in returns:
                    remove_scene.append(element[1]) #remove all scene points 
            #spoof is between two real returns
            else:
                for k, (r_scene, idx_scene) in enumerate(returns):
                    if r_scene > r:
                        # keep spoof
                        for element in returns[k:]:
                            remove_scene.append(element[1])
                        break 
    # print(trace_spherical.shape[0], remove_spoof)



    fn_points = np.concatenate([front_near_trace, selected_trace['points'][:, -2:]], axis = 1)
    scene_points = dataset[frame]['points'] 

    mask_remove_spoof = np.ones(fn_points.shape[0], dtype=bool)
    mask_remove_spoof[remove_spoof] = False
    fn_points_rc = fn_points[mask_remove_spoof]

    mask_remove_scene = np.ones(scene_points.shape[0], dtype=bool)
    mask_remove_scene[remove_scene] = False
    scene_points_rc = scene_points[mask_remove_scene]

    frame_points_spoof_rc = np.concatenate([scene_points_rc, fn_points_rc], axis = 0)



    # 2. Reload fresh data to be safe (aliasing prevention)
    dict_mod = dataset[frame] # Currently identical to clean

    # 3. Inject the spoofed points
    # Ensure shape is (N, 4) or (N, 5) matching the original
    dict_mod['points'] = frame_points_spoof_rc

    # 4. Remove old voxel data 
    # (Since we changed points, old voxels are invalid. 
    # prepare_data usually overwrites, but this prevents shape mismatch errors)
    for k in ['voxels', 'voxel_coords', 'voxel_num_points']:
        dict_mod.pop(k, None)

    # 5. Inject the missing 'gt_names'
    dict_mod   = helpers.inject_gt_names(dict_mod, dataset.class_names)
    dict_mod   = dataset.prepare_data(dict_mod)
    dict_mod['batch_size']   = 1

    load_data_to_gpu(dict_mod)
    batch_mod = helpers.convert_to_batch(dict_mod)

    model.eval()
    with torch.no_grad():
        pred_mod, _   = model.forward(batch_mod)
    # print("clean num boxes:", pred_clean[0]['pred_boxes'].shape[0])
    # print("mod   num boxes:", pred_mod[0]['pred_boxes'].shape[0])
    # Look at the raw scores before filtering
    raw_scores = pred_mod[0]['pred_scores']

    # candidate = []
    # for i in range (0, pred_mod[0]['pred_boxes'].shape[0]):
    #     x = pred_mod[0]['pred_boxes'][:, 0]
    #     y = pred_mod[0]['pred_boxes'][:, 1]
    #     if(x[i] >= 13 and x[i]<=17 and y[i]>=-5 and y[i]<=-1):
    #         candidate.append(i)
    #         print("prediction: ", i," |box location: ",  pred_mod[0]['pred_boxes'][i], " |score: ", pred_mod[0]['pred_scores'][3], " |label: ", pred_mod[0]['pred_labels'][3])



    pos_t = torch.from_numpy(position).to('cuda')
    val_t = torch.tensor([selected_trace['box'][2]], device='cuda')
    box_dim = torch.from_numpy(selected_trace['box'][3:6]).to('cuda')
    trace_box_c = torch.cat((pos_t, val_t, box_dim))
    d_trace = torch.linalg.norm(trace_box_c[:3])
    V_trace = selected_trace['box'][3]*selected_trace['box'][4]*selected_trace['box'][5]

    comparisons = []

    for i in range (0, pred_mod[0]['pred_boxes'].shape[0]):
        box = pred_mod[0]['pred_boxes'][i][:3]
        dim = pred_mod[0]['pred_boxes'][i][3:6]
        d_pred = torch.linalg.norm(box)
        V_pred = dim[0]*dim[1]*dim[2]
        label_pred = pred_mod[0]['pred_labels'][i].item()
        score_pred = pred_mod[0]['pred_scores'][i].item()

        d_d = np.round(torch.abs(d_pred - d_trace).item(), 2)
        d_V = np.round(torch.abs(V_pred - V_trace).item(), 2)
        d_label = label_pred - 1

        cos = helpers.cosine_similarity(trace_box_c[:3].float(), box)
        data = {
            "box" : box,
            "dim" : dim, 
            "distance" : d_d,
            "cos_sim" : cos,
            "volume" : d_V,
            "label" : label_pred,
            "score" : score_pred,
            "n_points": selected_trace['num_points']
        }
        comparisons.append(data)
        # print(f"index = {i} | d_distance: {d_d} | cos similarity: {np.round(cos.item(), 2)} | d_Volume:{d_V} | d_label: {d_label} | score: {np.round(score_pred, 2)}")

    best_idx = sorted(
        range(len(comparisons)),
        key=lambda i: (
            comparisons[i]["distance"],
            -comparisons[i]["cos_sim"],
            comparisons[i]["volume"]
        )
    )[0]

    # print("Best match index:", best_idx)
    if(comparisons[best_idx]['cos_sim'].item() > 0):
        print(f"n points: {selected_trace['num_points']} ", comparisons[best_idx])
        spoof_data_smaller.append(comparisons[best_idx])
    else:
        failed_attempts_smaller.append(comparisons[best_idx])
        print(f"NO PROPOSALS FOUND FOR TRACE WITH {trace['num_points']}")
        # print(box)
    # print(pred_mod[0]['pred_boxes'][best_idx])
    # print(trace_box_c)
# Out:
# n points: 93  {'box': tensor([14.8576, -3.0488,  0.9322], device='cuda:0'), 'dim': tensor([4.6710, 2.0362, 1.5051], device='cuda:0'), 'distance': 0.13, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.51, 'label': 1, 'score': 0.9104835391044617, 'n_points': 93}
# n points: 34  {'box': tensor([14.8831, -3.0693,  1.1021], device='cuda:0'), 'dim': tensor([4.7411, 2.1217, 1.6872], device='cuda:0'), 'distance': 0.09, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 3.17, 'label': 1, 'score': 0.839952826499939, 'n_points': 34}
# n points: 31  {'box': tensor([14.7731, -3.3164,  0.9883], device='cuda:0'), 'dim': tensor([4.5485, 2.0458, 1.5480], device='cuda:0'), 'distance': 0.15, 'cos_sim': tensor(0.9997, device='cuda:0'), 'volume': 0.6, 'label': 1, 'score': 0.5373139977455139, 'n_points': 31}
# n points: 32  {'box': tensor([15.0195, -2.8630,  0.7622], device='cuda:0'), 'dim': tensor([4.4274, 2.0463, 1.4873], device='cuda:0'), 'distance': 0.01, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.88, 'label': 1, 'score': 0.6848128437995911, 'n_points': 32}
# n points: 53  {'box': tensor([14.7949, -3.0659,  1.0434], device='cuda:0'), 'dim': tensor([4.4619, 2.0537, 1.6067], device='cuda:0'), 'distance': 0.18, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.92, 'label': 1, 'score': 0.8531538844108582, 'n_points': 53}
# n points: 42  {'box': tensor([14.9722, -2.9867,  0.8389], device='cuda:0'), 'dim': tensor([4.2356, 1.9940, 1.4474], device='cuda:0'), 'distance': 0.03, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.63, 'label': 1, 'score': 0.7706489562988281, 'n_points': 42}
# n points: 39  {'box': tensor([14.8520, -3.0101,  1.1124], device='cuda:0'), 'dim': tensor([4.6947, 2.1113, 1.6791], device='cuda:0'), 'distance': 0.13, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.84, 'label': 1, 'score': 0.7156010270118713, 'n_points': 39}
# n points: 44  {'box': tensor([15.0329, -3.0122,  0.8757], device='cuda:0'), 'dim': tensor([4.2797, 2.0099, 1.4517], device='cuda:0'), 'distance': 0.03, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.89, 'label': 1, 'score': 0.7829317450523376, 'n_points': 44}
# n points: 36  {'box': tensor([14.8140, -3.1045,  1.2186], device='cuda:0'), 'dim': tensor([4.5400, 2.0634, 1.6376], device='cuda:0'), 'distance': 0.15, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 1.53, 'label': 1, 'score': 0.7210507392883301, 'n_points': 36}
# n points: 49  {'box': tensor([14.9023, -3.0467,  0.8102], device='cuda:0'), 'dim': tensor([4.0645, 1.9375, 1.4363], device='cuda:0'), 'distance': 0.09, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.29, 'label': 1, 'score': 0.83650803565979, 'n_points': 49}
# NO PROPOSALS FOUND FOR TRACE WITH 32
# n points: 60  {'box': tensor([14.9751, -3.0506,  0.7360], device='cuda:0'), 'dim': tensor([4.1078, 1.9332, 1.3357], device='cuda:0'), 'distance': 0.01, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.99, 'label': 1, 'score': 0.7049857974052429, 'n_points': 60}
# n points: 71  {'box': tensor([14.9713, -3.0154,  0.7561], device='cuda:0'), 'dim': tensor([4.2203, 1.9719, 1.3926], device='cuda:0'), 'distance': 0.02, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.01, 'label': 1, 'score': 0.8062136769294739, 'n_points': 71}
# n points: 65  {'box': tensor([14.8675, -3.0448,  0.9010], device='cuda:0'), 'dim': tensor([4.4576, 1.9878, 1.5255], device='cuda:0'), 'distance': 0.12, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.37, 'label': 1, 'score': 0.7364024519920349, 'n_points': 65}
# n points: 72  {'box': tensor([15.0287, -2.9645,  0.6867], device='cuda:0'), 'dim': tensor([4.2400, 1.9630, 1.3476], device='cuda:0'), 'distance': 0.02, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.38, 'label': 1, 'score': 0.8414750695228577, 'n_points': 72}
# n points: 82  {'box': tensor([14.9645, -3.0450,  0.9073], device='cuda:0'), 'dim': tensor([4.5779, 2.0402, 1.5196], device='cuda:0'), 'distance': 0.02, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.04, 'label': 1, 'score': 0.8030763864517212, 'n_points': 82}
# n points: 91  {'box': tensor([14.9426, -3.0490,  0.6815], device='cuda:0'), 'dim': tensor([4.0929, 1.9468, 1.3907], device='cuda:0'), 'distance': 0.04, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.52, 'label': 1, 'score': 0.8566323518753052, 'n_points': 91}
# n points: 68  {'box': tensor([14.9053, -3.0575,  0.9225], device='cuda:0'), 'dim': tensor([4.5786, 2.0536, 1.5315], device='cuda:0'), 'distance': 0.08, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.25, 'label': 1, 'score': 0.8209148049354553, 'n_points': 68}
# n points: 58  {'box': tensor([14.8887, -3.0581,  0.9118], device='cuda:0'), 'dim': tensor([4.4822, 2.0234, 1.5220], device='cuda:0'), 'distance': 0.1, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.65, 'label': 1, 'score': 0.8059551119804382, 'n_points': 58}
# NO PROPOSALS FOUND FOR TRACE WITH 97
# n points: 47  {'box': tensor([14.9377, -3.0977,  1.0479], device='cuda:0'), 'dim': tensor([4.5107, 2.0506, 1.5610], device='cuda:0'), 'distance': 0.04, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.29, 'label': 1, 'score': 0.8111594319343567, 'n_points': 47}
# NO PROPOSALS FOUND FOR TRACE WITH 95
# n points: 44  {'box': tensor([14.8773, -3.0205,  1.0893], device='cuda:0'), 'dim': tensor([4.4188, 2.0115, 1.5886], device='cuda:0'), 'distance': 0.11, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.97, 'label': 1, 'score': 0.8333969712257385, 'n_points': 44}
# n points: 85  {'box': tensor([14.9577, -3.0297,  0.8989], device='cuda:0'), 'dim': tensor([4.4201, 1.9799, 1.5076], device='cuda:0'), 'distance': 0.03, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.06, 'label': 1, 'score': 0.906494140625, 'n_points': 85}
# n points: 71  {'box': tensor([14.9234, -2.9008,  1.6382], device='cuda:0'), 'dim': tensor([6.8185, 3.1482, 2.9253], device='cuda:0'), 'distance': 0.09, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 9.08, 'label': 1, 'score': 0.47337424755096436, 'n_points': 71}
# n points: 46  {'box': tensor([14.8843, -3.2487,  0.5520], device='cuda:0'), 'dim': tensor([3.9786, 1.8756, 1.4484], device='cuda:0'), 'distance': 0.06, 'cos_sim': tensor(0.9998, device='cuda:0'), 'volume': 5.31, 'label': 1, 'score': 0.14369581639766693, 'n_points': 46}
# n points: 37  {'box': tensor([14.9026, -3.0186,  1.0681], device='cuda:0'), 'dim': tensor([4.5001, 2.0609, 1.7031], device='cuda:0'), 'distance': 0.1, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.65, 'label': 1, 'score': 0.767218291759491, 'n_points': 37}
# n points: 55  {'box': tensor([14.9455, -2.9979,  0.8721], device='cuda:0'), 'dim': tensor([4.4813, 2.0117, 1.4686], device='cuda:0'), 'distance': 0.05, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.11, 'label': 1, 'score': 0.8820862770080566, 'n_points': 55}
# n points: 46  {'box': tensor([14.7386, -3.4551,  1.4679], device='cuda:0'), 'dim': tensor([6.3062, 2.7434, 2.4853], device='cuda:0'), 'distance': 0.17, 'cos_sim': tensor(0.9995, device='cuda:0'), 'volume': 10.72, 'label': 1, 'score': 0.16827981173992157, 'n_points': 46}
# n points: 55  {'box': tensor([14.9862, -2.8924,  0.6652], device='cuda:0'), 'dim': tensor([4.3695, 2.0237, 1.4161], device='cuda:0'), 'distance': 0.03, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 3.59, 'label': 1, 'score': 0.2903549075126648, 'n_points': 55}
# n points: 33  {'box': tensor([14.8714, -2.9331,  1.0631], device='cuda:0'), 'dim': tensor([4.4722, 2.0475, 1.6658], device='cuda:0'), 'distance': 0.14, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.1, 'label': 1, 'score': 0.7805705070495605, 'n_points': 33}
# n points: 46  {'box': tensor([14.9189, -2.9702,  0.8098], device='cuda:0'), 'dim': tensor([4.4408, 1.9930, 1.4724], device='cuda:0'), 'distance': 0.08, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.9, 'label': 1, 'score': 0.8727082014083862, 'n_points': 46}
# n points: 83  {'box': tensor([15.0643, -2.9661,  0.6207], device='cuda:0'), 'dim': tensor([4.6105, 2.0681, 1.4060], device='cuda:0'), 'distance': 0.06, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.71, 'label': 1, 'score': 0.8051314949989319, 'n_points': 83}
# n points: 36  {'box': tensor([15.0067, -3.0863,  0.9505], device='cuda:0'), 'dim': tensor([4.5112, 2.0676, 1.5691], device='cuda:0'), 'distance': 0.03, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.5, 'label': 1, 'score': 0.7963014841079712, 'n_points': 36}
# n points: 39  {'box': tensor([15.0267, -3.1249,  1.1147], device='cuda:0'), 'dim': tensor([4.4775, 2.0535, 1.6053], device='cuda:0'), 'distance': 0.06, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.63, 'label': 1, 'score': 0.7147337198257446, 'n_points': 39}
# NO PROPOSALS FOUND FOR TRACE WITH 32
# n points: 38  {'box': tensor([14.9140, -3.4520,  0.6444], device='cuda:0'), 'dim': tensor([4.1981, 1.8658, 1.4479], device='cuda:0'), 'distance': 0.02, 'cos_sim': tensor(0.9995, device='cuda:0'), 'volume': 3.98, 'label': 1, 'score': 0.2934340536594391, 'n_points': 38}
# n points: 58  {'box': tensor([14.9796, -3.4497,  0.6962], device='cuda:0'), 'dim': tensor([4.4120, 1.9354, 1.5161], device='cuda:0'), 'distance': 0.08, 'cos_sim': tensor(0.9996, device='cuda:0'), 'volume': 2.38, 'label': 1, 'score': 0.3645266890525818, 'n_points': 58}
# n points: 69  {'box': tensor([15.0209, -2.9981,  0.8254], device='cuda:0'), 'dim': tensor([4.6632, 2.1166, 1.5078], device='cuda:0'), 'distance': 0.03, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.44, 'label': 1, 'score': 0.7126547694206238, 'n_points': 69}
# n points: 86  {'box': tensor([14.9611, -2.9970,  0.7885], device='cuda:0'), 'dim': tensor([4.5520, 2.0691, 1.4798], device='cuda:0'), 'distance': 0.03, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.39, 'label': 1, 'score': 0.7934964299201965, 'n_points': 86}
# n points: 80  {'box': tensor([15.0490, -3.0689,  0.7823], device='cuda:0'), 'dim': tensor([4.6702, 2.0803, 1.4420], device='cuda:0'), 'distance': 0.06, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.31, 'label': 1, 'score': 0.829973042011261, 'n_points': 80}
# n points: 90  {'box': tensor([14.8962, -2.9632,  0.9924], device='cuda:0'), 'dim': tensor([4.6387, 2.0960, 1.5679], device='cuda:0'), 'distance': 0.11, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.38, 'label': 1, 'score': 0.9095219969749451, 'n_points': 90}
# n points: 73  {'box': tensor([14.8507, -3.0336,  1.0789], device='cuda:0'), 'dim': tensor([4.5835, 2.0853, 1.6388], device='cuda:0'), 'distance': 0.14, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.04, 'label': 1, 'score': 0.8639601469039917, 'n_points': 73}
# n points: 80  {'box': tensor([14.8913, -3.0330,  1.0501], device='cuda:0'), 'dim': tensor([4.6495, 2.0798, 1.5429], device='cuda:0'), 'distance': 0.11, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.7, 'label': 1, 'score': 0.908856987953186, 'n_points': 80}
# NO PROPOSALS FOUND FOR TRACE WITH 50
# n points: 59  {'box': tensor([14.9112, -2.9948,  1.0815], device='cuda:0'), 'dim': tensor([4.6522, 2.1807, 1.7650], device='cuda:0'), 'distance': 0.1, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.28, 'label': 1, 'score': 0.7761548161506653, 'n_points': 59}
# NO PROPOSALS FOUND FOR TRACE WITH 75
# n points: 42  {'box': tensor([14.8326, -2.9149,  1.0688], device='cuda:0'), 'dim': tensor([4.5604, 2.1058, 1.7216], device='cuda:0'), 'distance': 0.19, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.91, 'label': 1, 'score': 0.8246172070503235, 'n_points': 42}
# n points: 39  {'box': tensor([14.8254, -3.0612,  1.2155], device='cuda:0'), 'dim': tensor([4.5517, 2.0999, 1.7968], device='cuda:0'), 'distance': 0.15, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.55, 'label': 1, 'score': 0.7659733891487122, 'n_points': 39}
# n points: 58  {'box': tensor([15.0140, -3.0142,  0.8276], device='cuda:0'), 'dim': tensor([4.2125, 1.9496, 1.5037], device='cuda:0'), 'distance': 0.01, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.75, 'label': 1, 'score': 0.6162915229797363, 'n_points': 58}
# n points: 96  {'box': tensor([15.0148, -2.9607,  0.8396], device='cuda:0'), 'dim': tensor([4.3197, 1.9976, 1.5043], device='cuda:0'), 'distance': 0.0, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.38, 'label': 1, 'score': 0.8560057282447815, 'n_points': 96}
# n points: 94  {'box': tensor([14.9892, -2.9952,  0.9495], device='cuda:0'), 'dim': tensor([4.1907, 1.9514, 1.5210], device='cuda:0'), 'distance': 0.01, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.84, 'label': 1, 'score': 0.8661236763000488, 'n_points': 94}
# n points: 77  {'box': tensor([14.9838, -3.0473,  0.9121], device='cuda:0'), 'dim': tensor([4.3683, 2.0522, 1.6129], device='cuda:0'), 'distance': 0.01, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.86, 'label': 1, 'score': 0.8368991017341614, 'n_points': 77}
# n points: 32  {'box': tensor([14.9863, -2.9478,  1.0282], device='cuda:0'), 'dim': tensor([4.4380, 2.0270, 1.5410], device='cuda:0'), 'distance': 0.04, 'cos_sim': tensor(0.9998, device='cuda:0'), 'volume': 2.35, 'label': 1, 'score': 0.709037721157074, 'n_points': 32}
# n points: 66  {'box': tensor([14.9281, -2.9894,  0.8334], device='cuda:0'), 'dim': tensor([4.2419, 2.0067, 1.4720], device='cuda:0'), 'distance': 0.08, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.93, 'label': 1, 'score': 0.8779961466789246, 'n_points': 66}
# n points: 43  {'box': tensor([14.9721, -3.2533,  1.0854], device='cuda:0'), 'dim': tensor([4.2458, 1.9830, 1.6463], device='cuda:0'), 'distance': 0.01, 'cos_sim': tensor(0.9998, device='cuda:0'), 'volume': 2.36, 'label': 1, 'score': 0.1804954558610916, 'n_points': 43}
# n points: 57  {'box': tensor([14.9584, -3.0129,  0.7764], device='cuda:0'), 'dim': tensor([4.3332, 2.0299, 1.4423], device='cuda:0'), 'distance': 0.05, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 1.09, 'label': 1, 'score': 0.8605265617370605, 'n_points': 57}
# n points: 47  {'box': tensor([15.0213, -2.8178,  1.0439], device='cuda:0'), 'dim': tensor([4.4607, 2.0405, 1.5502], device='cuda:0'), 'distance': 0.03, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 2.11, 'label': 1, 'score': 0.7819572687149048, 'n_points': 47}
# n points: 33  {'box': tensor([15.0617, -2.9286,  1.1757], device='cuda:0'), 'dim': tensor([4.5832, 2.1096, 1.8209], device='cuda:0'), 'distance': 0.03, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 0.8, 'label': 1, 'score': 0.6532766819000244, 'n_points': 33}
# n points: 45  {'box': tensor([14.9405, -2.9764,  0.8843], device='cuda:0'), 'dim': tensor([4.2256, 2.0157, 1.5057], device='cuda:0'), 'distance': 0.06, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.23, 'label': 1, 'score': 0.8258584141731262, 'n_points': 45}
# n points: 49  {'box': tensor([14.7657, -3.1137,  0.9784], device='cuda:0'), 'dim': tensor([4.2934, 1.9906, 1.6956], device='cuda:0'), 'distance': 0.2, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 1.62, 'label': 1, 'score': 0.7234236598014832, 'n_points': 49}
# n points: 71  {'box': tensor([15.0071, -2.8572,  1.0181], device='cuda:0'), 'dim': tensor([4.4062, 2.0066, 1.4950], device='cuda:0'), 'distance': 0.03, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 3.0, 'label': 1, 'score': 0.8077937960624695, 'n_points': 71}
# n points: 33  {'box': tensor([14.9746, -2.9679,  0.8131], device='cuda:0'), 'dim': tensor([4.2459, 1.9878, 1.4569], device='cuda:0'), 'distance': 0.03, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.7, 'label': 1, 'score': 0.7882908582687378, 'n_points': 33}
# NO PROPOSALS FOUND FOR TRACE WITH 33
# n points: 80  {'box': tensor([14.9349, -3.0252,  1.0208], device='cuda:0'), 'dim': tensor([4.5001, 2.0834, 1.7226], device='cuda:0'), 'distance': 0.05, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.04, 'label': 1, 'score': 0.8738402128219604, 'n_points': 80}
# n points: 81  {'box': tensor([15.0366, -2.8823,  0.9732], device='cuda:0'), 'dim': tensor([4.5194, 2.0525, 1.5393], device='cuda:0'), 'distance': 0.01, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.94, 'label': 1, 'score': 0.7987133264541626, 'n_points': 81}
# n points: 42  {'box': tensor([15.0012, -2.9683,  0.9064], device='cuda:0'), 'dim': tensor([4.2492, 1.9956, 1.5416], device='cuda:0'), 'distance': 0.01, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.48, 'label': 1, 'score': 0.822081446647644, 'n_points': 42}
# n points: 43  {'box': tensor([14.8397, -2.9659,  1.2400], device='cuda:0'), 'dim': tensor([4.9289, 2.2543, 1.8151], device='cuda:0'), 'distance': 0.16, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.7, 'label': 1, 'score': 0.8197798728942871, 'n_points': 43}
# n points: 59  {'box': tensor([14.9136, -3.0254,  1.0556], device='cuda:0'), 'dim': tensor([4.5361, 2.0981, 1.8327], device='cuda:0'), 'distance': 0.07, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 1.33, 'label': 1, 'score': 0.8100146651268005, 'n_points': 59}
# n points: 100  {'box': tensor([14.9888, -2.9169,  0.9209], device='cuda:0'), 'dim': tensor([4.4441, 1.9946, 1.4954], device='cuda:0'), 'distance': 0.03, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.96, 'label': 1, 'score': 0.8555986285209656, 'n_points': 100}
# n points: 31  {'box': tensor([14.7899, -3.0170,  1.2173], device='cuda:0'), 'dim': tensor([4.8922, 2.2589, 1.8493], device='cuda:0'), 'distance': 0.2, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.43, 'label': 1, 'score': 0.8065879940986633, 'n_points': 31}
# n points: 55  {'box': tensor([14.8759, -2.9982,  0.9096], device='cuda:0'), 'dim': tensor([4.4913, 2.0577, 1.5736], device='cuda:0'), 'distance': 0.12, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.57, 'label': 1, 'score': 0.8146241307258606, 'n_points': 55}
# n points: 52  {'box': tensor([14.8900, -2.9082,  1.3417], device='cuda:0'), 'dim': tensor([4.8914, 2.2408, 1.8157], device='cuda:0'), 'distance': 0.12, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.97, 'label': 1, 'score': 0.7876627445220947, 'n_points': 52}
# n points: 33  {'box': tensor([14.9019, -3.2460,  0.8824], device='cuda:0'), 'dim': tensor([4.7496, 2.1113, 1.6585], device='cuda:0'), 'distance': 0.04, 'cos_sim': tensor(0.9998, device='cuda:0'), 'volume': 0.52, 'label': 1, 'score': 0.16216249763965607, 'n_points': 33}
# NO PROPOSALS FOUND FOR TRACE WITH 44
# n points: 72  {'box': tensor([14.8725, -2.9533,  1.2636], device='cuda:0'), 'dim': tensor([4.9128, 2.2355, 1.8283], device='cuda:0'), 'distance': 0.13, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.79, 'label': 1, 'score': 0.8650937080383301, 'n_points': 72}
# n points: 46  {'box': tensor([14.9191, -3.0090,  0.9435], device='cuda:0'), 'dim': tensor([4.4628, 2.0642, 1.6347], device='cuda:0'), 'distance': 0.07, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.05, 'label': 1, 'score': 0.784005343914032, 'n_points': 46}
# n points: 40  {'box': tensor([15.0107, -3.0275,  0.9732], device='cuda:0'), 'dim': tensor([4.5177, 2.0263, 1.4725], device='cuda:0'), 'distance': 0.01, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 3.33, 'label': 1, 'score': 0.8212683796882629, 'n_points': 40}
# n points: 82  {'box': tensor([14.8655, -2.9588,  1.2086], device='cuda:0'), 'dim': tensor([4.7520, 2.1787, 1.7554], device='cuda:0'), 'distance': 0.13, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 4.69, 'label': 1, 'score': 0.8656432628631592, 'n_points': 82}
# n points: 41  {'box': tensor([14.9830, -3.0758,  1.0642], device='cuda:0'), 'dim': tensor([4.4630, 2.0784, 1.6807], device='cuda:0'), 'distance': 0.0, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.52, 'label': 1, 'score': 0.6989102959632874, 'n_points': 41}
# n points: 91  {'box': tensor([14.8777, -3.0187,  1.0847], device='cuda:0'), 'dim': tensor([4.7745, 2.1608, 1.7147], device='cuda:0'), 'distance': 0.11, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 5.18, 'label': 1, 'score': 0.8821444511413574, 'n_points': 91}
# n points: 32  {'box': tensor([15.0200, -2.9975,  1.1766], device='cuda:0'), 'dim': tensor([4.5981, 2.1515, 1.8451], device='cuda:0'), 'distance': 0.02, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.14, 'label': 1, 'score': 0.7001475691795349, 'n_points': 32}
# n points: 76  {'box': tensor([14.9965, -2.8821,  0.8800], device='cuda:0'), 'dim': tensor([4.6852, 2.1002, 1.5207], device='cuda:0'), 'distance': 0.03, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.36, 'label': 1, 'score': 0.8731854557991028, 'n_points': 76}
# NO PROPOSALS FOUND FOR TRACE WITH 91
# n points: 56  {'box': tensor([14.9385, -3.2382,  0.8655], device='cuda:0'), 'dim': tensor([4.5606, 2.0630, 1.5402], device='cuda:0'), 'distance': 0.01, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 0.83, 'label': 1, 'score': 0.17620116472244263, 'n_points': 56}
# n points: 54  {'box': tensor([15.0001, -2.8658,  0.9289], device='cuda:0'), 'dim': tensor([4.5995, 2.1033, 1.5468], device='cuda:0'), 'distance': 0.02, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.36, 'label': 1, 'score': 0.8109330534934998, 'n_points': 54}
# n points: 37  {'box': tensor([14.7550, -3.4255,  0.5852], device='cuda:0'), 'dim': tensor([2.3775, 1.4482, 1.4329], device='cuda:0'), 'distance': 0.14, 'cos_sim': tensor(0.9993, device='cuda:0'), 'volume': 3.14, 'label': 1, 'score': 0.19094456732273102, 'n_points': 37}
# n points: 59  {'box': tensor([14.9978, -2.9960,  0.9671], device='cuda:0'), 'dim': tensor([4.6250, 2.1045, 1.5483], device='cuda:0'), 'distance': 0.0, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.25, 'label': 1, 'score': 0.819139838218689, 'n_points': 59}
# n points: 55  {'box': tensor([14.8802, -3.4282,  0.8112], device='cuda:0'), 'dim': tensor([2.8689, 1.2638, 1.5476], device='cuda:0'), 'distance': 0.03, 'cos_sim': tensor(0.9996, device='cuda:0'), 'volume': 18.63, 'label': 1, 'score': 0.24354711174964905, 'n_points': 55}
# n points: 51  {'box': tensor([15.0046, -3.1419,  0.5537], device='cuda:0'), 'dim': tensor([3.8196, 1.7466, 1.4785], device='cuda:0'), 'distance': 0.04, 'cos_sim': tensor(0.9996, device='cuda:0'), 'volume': 1.79, 'label': 1, 'score': 0.1829954981803894, 'n_points': 51}
# n points: 43  {'box': tensor([14.9971, -2.8824,  0.9580], device='cuda:0'), 'dim': tensor([4.5885, 2.1151, 1.6171], device='cuda:0'), 'distance': 0.03, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.37, 'label': 1, 'score': 0.7179034352302551, 'n_points': 43}
# n points: 68  {'box': tensor([15.0258, -3.3771,  0.9426], device='cuda:0'), 'dim': tensor([4.3830, 1.9444, 1.9224], device='cuda:0'), 'distance': 0.11, 'cos_sim': tensor(0.9997, device='cuda:0'), 'volume': 7.86, 'label': 1, 'score': 0.16413794457912445, 'n_points': 68}
# n points: 54  {'box': tensor([14.9528, -3.0212,  0.5813], device='cuda:0'), 'dim': tensor([2.9390, 1.1359, 1.1070], device='cuda:0'), 'distance': 0.03, 'cos_sim': tensor(0.9997, device='cuda:0'), 'volume': 4.38, 'label': 1, 'score': 0.2500748038291931, 'n_points': 54}
# n points: 40  {'box': tensor([14.9733, -2.8886,  0.9826], device='cuda:0'), 'dim': tensor([4.5362, 2.0877, 1.5934], device='cuda:0'), 'distance': 0.05, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.23, 'label': 1, 'score': 0.7665167450904846, 'n_points': 40}
# n points: 64  {'box': tensor([15.0505, -2.6704,  0.9076], device='cuda:0'), 'dim': tensor([4.2366, 2.0199, 1.6779], device='cuda:0'), 'distance': 0.01, 'cos_sim': tensor(0.9998, device='cuda:0'), 'volume': 9.89, 'label': 1, 'score': 0.41129934787750244, 'n_points': 64}
# n points: 54  {'box': tensor([14.8010, -3.5039,  0.5183], device='cuda:0'), 'dim': tensor([3.6610, 2.1228, 1.5270], device='cuda:0'), 'distance': 0.08, 'cos_sim': tensor(0.9992, device='cuda:0'), 'volume': 3.79, 'label': 1, 'score': 0.16148538887500763, 'n_points': 54}
# n points: 36  {'box': tensor([14.8597, -2.9949,  0.9927], device='cuda:0'), 'dim': tensor([4.4199, 2.0734, 1.6516], device='cuda:0'), 'distance': 0.15, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.19, 'label': 1, 'score': 0.6023215055465698, 'n_points': 36}
# n points: 77  {'box': tensor([15.0205, -2.7484,  0.7901], device='cuda:0'), 'dim': tensor([3.7699, 2.1572, 1.6225], device='cuda:0'), 'distance': 0.03, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 11.05, 'label': 1, 'score': 0.36876288056373596, 'n_points': 77}
# n points: 77  {'box': tensor([14.9756, -3.0689,  0.5364], device='cuda:0'), 'dim': tensor([3.5060, 1.6621, 1.4057], device='cuda:0'), 'distance': 0.0, 'cos_sim': tensor(0.9997, device='cuda:0'), 'volume': 0.11, 'label': 1, 'score': 0.2749272882938385, 'n_points': 77}
# n points: 73  {'box': tensor([15.0928, -3.3219,  0.8505], device='cuda:0'), 'dim': tensor([3.8324, 1.8714, 1.8506], device='cuda:0'), 'distance': 0.16, 'cos_sim': tensor(0.9998, device='cuda:0'), 'volume': 10.97, 'label': 1, 'score': 0.17370964586734772, 'n_points': 73}

# %%
for i, trace in enumerate(traces_bigger):    
    selected_trace = trace
    centered_points_trace = selected_trace['points'][:, :2] - selected_trace['box'][:2]
    position = np.array([15, -3])

    angle = 0
    if(selected_trace['box'][0]<0):
        # print("rear object")
        angle = np.pi

    c = np.cos(angle)
    s = np.sin(angle)
    R = np.array([[c, -s],
                  [s, c]])


    rotated_trace = centered_points_trace @ R.T
    front_near_trace_planar = rotated_trace + position
    front_near_trace = np.concatenate([front_near_trace_planar, selected_trace['points'][:, 2].reshape(-1, 1)], axis = 1)

    # helpers.plot_trace(front_near_trace)

    importlib.reload(helpers)
    r_trace, theta_trace, phi_trace = helpers.cart_2_spherical(front_near_trace)
    scene_points = dataset[frame]['points'][:, :3]
    r_scene, theta_scene, phi_scene = helpers.cart_2_spherical(scene_points)

    trace_spherical = np.concatenate([r_trace.reshape(-1, 1), theta_trace.reshape(-1, 1), phi_trace.reshape(-1, 1)], axis = 1)
    scene_spherical = np.concatenate([r_scene.reshape(-1, 1), theta_scene.reshape(-1, 1), phi_scene.reshape(-1, 1)], axis = 1)

    azimuths = np.deg2rad(np.arange(0, 360.1, np.deg2rad(0.1358)))
    elevations = np.load('waymo_top_lidar_inclinations.npy')


    Grid = defaultdict(list)
    dtheta = np.deg2rad(0.1358)
    for idx, (r, theta, phi) in enumerate(scene_spherical):
        az = theta % (2*np.pi)
        az_idx = int(np.floor(az/dtheta))
        beam_idx = np.argmin(np.abs(elevations-phi))
        Grid[(az_idx, beam_idx)].append((r, idx))
    for key in Grid:
        Grid[key].sort(key=lambda x: x[0])  # sort by range


    remove_spoof = []
    remove_scene = []
    for idx, (r, theta, phi) in enumerate(trace_spherical):
        az = theta % (2*np.pi)
        az_idx = int(np.floor(az/dtheta))
        beam_idx = np.argmin(np.abs(elevations-phi))
        returns = Grid[(az_idx, beam_idx)]
        if(len(returns) == 0):
            continue
        else:
            # spoof point is behind first real return, remove it
            if returns[0][0] < r:
                # print(round(azimuths[az_idx], 4), round(elevations[beam_idx], 4), round(r, 4), returns[0][0], returns[0][1])
                #ranges are already sorted in ascending order
                remove_spoof.append(idx)
            #spoof is front of all real returns
            elif r < returns[0][0]:
                for element in returns:
                    remove_scene.append(element[1]) #remove all scene points 
            #spoof is between two real returns
            else:
                for k, (r_scene, idx_scene) in enumerate(returns):
                    if r_scene > r:
                        # keep spoof
                        for element in returns[k:]:
                            remove_scene.append(element[1])
                        break 
    # print(trace_spherical.shape[0], remove_spoof)



    fn_points = np.concatenate([front_near_trace, selected_trace['points'][:, -2:]], axis = 1)
    scene_points = dataset[frame]['points'] 

    mask_remove_spoof = np.ones(fn_points.shape[0], dtype=bool)
    mask_remove_spoof[remove_spoof] = False
    fn_points_rc = fn_points[mask_remove_spoof]

    mask_remove_scene = np.ones(scene_points.shape[0], dtype=bool)
    mask_remove_scene[remove_scene] = False
    scene_points_rc = scene_points[mask_remove_scene]

    frame_points_spoof_rc = np.concatenate([scene_points_rc, fn_points_rc], axis = 0)



    # 2. Reload fresh data to be safe (aliasing prevention)
    dict_mod = dataset[frame] # Currently identical to clean

    # 3. Inject the spoofed points
    # Ensure shape is (N, 4) or (N, 5) matching the original
    dict_mod['points'] = frame_points_spoof_rc

    # 4. Remove old voxel data 
    # (Since we changed points, old voxels are invalid. 
    # prepare_data usually overwrites, but this prevents shape mismatch errors)
    for k in ['voxels', 'voxel_coords', 'voxel_num_points']:
        dict_mod.pop(k, None)

    # 5. Inject the missing 'gt_names'
    dict_mod   = helpers.inject_gt_names(dict_mod, dataset.class_names)
    dict_mod   = dataset.prepare_data(dict_mod)
    dict_mod['batch_size']   = 1

    load_data_to_gpu(dict_mod)
    batch_mod = helpers.convert_to_batch(dict_mod)

    model.eval()
    with torch.no_grad():
        pred_mod, _   = model.forward(batch_mod)
    # print("clean num boxes:", pred_clean[0]['pred_boxes'].shape[0])
    # print("mod   num boxes:", pred_mod[0]['pred_boxes'].shape[0])
    # Look at the raw scores before filtering
    raw_scores = pred_mod[0]['pred_scores']

    # candidate = []
    # for i in range (0, pred_mod[0]['pred_boxes'].shape[0]):
    #     x = pred_mod[0]['pred_boxes'][:, 0]
    #     y = pred_mod[0]['pred_boxes'][:, 1]
    #     if(x[i] >= 13 and x[i]<=17 and y[i]>=-5 and y[i]<=-1):
    #         candidate.append(i)
    #         print("prediction: ", i," |box location: ",  pred_mod[0]['pred_boxes'][i], " |score: ", pred_mod[0]['pred_scores'][3], " |label: ", pred_mod[0]['pred_labels'][3])



    pos_t = torch.from_numpy(position).to('cuda')
    val_t = torch.tensor([selected_trace['box'][2]], device='cuda')
    box_dim = torch.from_numpy(selected_trace['box'][3:6]).to('cuda')
    trace_box_c = torch.cat((pos_t, val_t, box_dim))
    d_trace = torch.linalg.norm(trace_box_c[:3])
    V_trace = selected_trace['box'][3]*selected_trace['box'][4]*selected_trace['box'][5]

    comparisons = []

    for i in range (0, pred_mod[0]['pred_boxes'].shape[0]):
        box = pred_mod[0]['pred_boxes'][i][:3]
        dim = pred_mod[0]['pred_boxes'][i][3:6]
        d_pred = torch.linalg.norm(box)
        V_pred = dim[0]*dim[1]*dim[2]
        label_pred = pred_mod[0]['pred_labels'][i].item()
        score_pred = pred_mod[0]['pred_scores'][i].item()

        d_d = np.round(torch.abs(d_pred - d_trace).item(), 2)
        d_V = np.round(torch.abs(V_pred - V_trace).item(), 2)
        d_label = label_pred - 1

        cos = helpers.cosine_similarity(trace_box_c[:3].float(), box)
        data = {
            "box" : box,
            "dim" : dim, 
            "distance" : d_d,
            "cos_sim" : cos,
            "volume" : d_V,
            "label" : label_pred,
            "score" : score_pred,
            "n_points": selected_trace['num_points']
        }
        comparisons.append(data)
        # print(f"index = {i} | d_distance: {d_d} | cos similarity: {np.round(cos.item(), 2)} | d_Volume:{d_V} | d_label: {d_label} | score: {np.round(score_pred, 2)}")

    best_idx = sorted(
        range(len(comparisons)),
        key=lambda i: (
            comparisons[i]["distance"],
            -comparisons[i]["cos_sim"],
            comparisons[i]["volume"]
        )
    )[0]

    # print("Best match index:", best_idx)
    if(comparisons[best_idx]['cos_sim'].item() > 0):
        print(f"n points: {selected_trace['num_points']} ", comparisons[best_idx])
        spoof_data_bigger.append(comparisons[best_idx])
    else:
        failed_attempts_bigger.append(comparisons[best_idx])
        print(f"NO PROPOSALS FOUND FOR TRACE WITH {trace['num_points']}")
        # print(box)
    # print(pred_mod[0]['pred_boxes'][best_idx])
    # print(trace_box_c)
# Out:
# n points: 114  {'box': tensor([14.7904, -3.0548,  0.8286], device='cuda:0'), 'dim': tensor([4.5219, 1.9973, 1.4940], device='cuda:0'), 'distance': 0.19, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.31, 'label': 1, 'score': 0.91007399559021, 'n_points': 114}
# n points: 111  {'box': tensor([14.9938, -3.0253,  0.8904], device='cuda:0'), 'dim': tensor([4.6697, 2.1300, 1.4580], device='cuda:0'), 'distance': 0.01, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.12, 'label': 1, 'score': 0.8722473978996277, 'n_points': 111}
# n points: 124  {'box': tensor([14.8875, -3.0536,  0.7833], device='cuda:0'), 'dim': tensor([4.5075, 2.0455, 1.4068], device='cuda:0'), 'distance': 0.1, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.65, 'label': 1, 'score': 0.8743449449539185, 'n_points': 124}
# n points: 105  {'box': tensor([14.8124, -2.9400,  0.6765], device='cuda:0'), 'dim': tensor([4.5155, 2.0099, 1.4007], device='cuda:0'), 'distance': 0.2, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.91, 'label': 1, 'score': 0.8836798071861267, 'n_points': 105}
# n points: 192  {'box': tensor([14.8854, -3.0009,  0.6897], device='cuda:0'), 'dim': tensor([4.4953, 2.0410, 1.3381], device='cuda:0'), 'distance': 0.11, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 3.35, 'label': 1, 'score': 0.9175055027008057, 'n_points': 192}
# n points: 181  {'box': tensor([14.9766, -3.0736,  0.9381], device='cuda:0'), 'dim': tensor([4.6336, 2.0201, 1.5640], device='cuda:0'), 'distance': 0.01, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.49, 'label': 1, 'score': 0.9077455401420593, 'n_points': 181}
# NO PROPOSALS FOUND FOR TRACE WITH 199
# n points: 142  {'box': tensor([15.0093, -3.0861,  0.8885], device='cuda:0'), 'dim': tensor([4.7382, 2.0553, 1.5253], device='cuda:0'), 'distance': 0.03, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.71, 'label': 1, 'score': 0.8443958163261414, 'n_points': 142}
# NO PROPOSALS FOUND FOR TRACE WITH 159
# NO PROPOSALS FOUND FOR TRACE WITH 162
# NO PROPOSALS FOUND FOR TRACE WITH 129
# n points: 109  {'box': tensor([15.0615, -3.0375,  0.6709], device='cuda:0'), 'dim': tensor([4.0526, 1.9181, 1.3638], device='cuda:0'), 'distance': 0.07, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.0, 'label': 1, 'score': 0.7704824805259705, 'n_points': 109}
# NO PROPOSALS FOUND FOR TRACE WITH 114
# n points: 133  {'box': tensor([15.0059, -2.9946,  0.6683], device='cuda:0'), 'dim': tensor([3.9841, 1.8761, 1.3407], device='cuda:0'), 'distance': 0.01, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.58, 'label': 1, 'score': 0.8473228216171265, 'n_points': 133}
# n points: 152  {'box': tensor([14.9392, -3.0600,  0.7942], device='cuda:0'), 'dim': tensor([4.4250, 1.9682, 1.4649], device='cuda:0'), 'distance': 0.04, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.63, 'label': 1, 'score': 0.909814715385437, 'n_points': 152}
# n points: 164  {'box': tensor([15.0642, -2.9670,  0.6437], device='cuda:0'), 'dim': tensor([4.0805, 1.8933, 1.3241], device='cuda:0'), 'distance': 0.06, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.37, 'label': 1, 'score': 0.8505561947822571, 'n_points': 164}
# n points: 113  {'box': tensor([14.9557, -3.0988,  0.8594], device='cuda:0'), 'dim': tensor([4.4566, 1.9979, 1.4683], device='cuda:0'), 'distance': 0.02, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.94, 'label': 1, 'score': 0.8782308101654053, 'n_points': 113}
# n points: 195  {'box': tensor([15.0955, -2.9290,  0.6287], device='cuda:0'), 'dim': tensor([4.1408, 1.9112, 1.3265], device='cuda:0'), 'distance': 0.08, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.1, 'label': 1, 'score': 0.7773498892784119, 'n_points': 195}
# n points: 102  {'box': tensor([15.0541, -2.9263,  0.6652], device='cuda:0'), 'dim': tensor([4.6725, 2.0718, 1.4660], device='cuda:0'), 'distance': 0.04, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.92, 'label': 1, 'score': 0.8125529885292053, 'n_points': 102}
# NO PROPOSALS FOUND FOR TRACE WITH 196
# n points: 179  {'box': tensor([15.0418, -2.9674,  0.6488], device='cuda:0'), 'dim': tensor([4.5809, 2.0393, 1.4477], device='cuda:0'), 'distance': 0.04, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.59, 'label': 1, 'score': 0.8931984305381775, 'n_points': 179}
# n points: 169  {'box': tensor([14.9173, -2.9901,  0.7818], device='cuda:0'), 'dim': tensor([4.7444, 2.0827, 1.4679], device='cuda:0'), 'distance': 0.08, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.12, 'label': 1, 'score': 0.9230697751045227, 'n_points': 169}
# n points: 147  {'box': tensor([14.9110, -3.0009,  0.8660], device='cuda:0'), 'dim': tensor([4.6604, 2.0613, 1.5028], device='cuda:0'), 'distance': 0.08, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.19, 'label': 1, 'score': 0.9115456342697144, 'n_points': 147}
# n points: 199  {'box': tensor([14.8149, -2.9954,  0.9954], device='cuda:0'), 'dim': tensor([4.7626, 2.1363, 1.6515], device='cuda:0'), 'distance': 0.18, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.18, 'label': 1, 'score': 0.8563982248306274, 'n_points': 199}
# n points: 110  {'box': tensor([15.0253, -2.9510,  0.8032], device='cuda:0'), 'dim': tensor([4.7218, 2.1000, 1.4795], device='cuda:0'), 'distance': 0.02, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.65, 'label': 1, 'score': 0.817844808101654, 'n_points': 110}
# n points: 117  {'box': tensor([14.8874, -3.0204,  0.9210], device='cuda:0'), 'dim': tensor([4.6734, 2.0946, 1.5400], device='cuda:0'), 'distance': 0.11, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.55, 'label': 1, 'score': 0.9132816791534424, 'n_points': 117}
# NO PROPOSALS FOUND FOR TRACE WITH 200
# n points: 200  {'box': tensor([14.8122, -3.0055,  1.0222], device='cuda:0'), 'dim': tensor([4.6847, 2.1015, 1.6776], device='cuda:0'), 'distance': 0.18, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.47, 'label': 1, 'score': 0.8670366406440735, 'n_points': 200}
# NO PROPOSALS FOUND FOR TRACE WITH 191
# NO PROPOSALS FOUND FOR TRACE WITH 192
# NO PROPOSALS FOUND FOR TRACE WITH 128
# NO PROPOSALS FOUND FOR TRACE WITH 143
# n points: 165  {'box': tensor([14.9050, -2.9481,  1.7326], device='cuda:0'), 'dim': tensor([7.0429, 2.9271, 3.0523], device='cuda:0'), 'distance': 0.12, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 4.47, 'label': 1, 'score': 0.7975165247917175, 'n_points': 165}
# n points: 121  {'box': tensor([15.0121, -2.9793,  0.8869], device='cuda:0'), 'dim': tensor([4.2708, 1.9812, 1.5743], device='cuda:0'), 'distance': 0.0, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.72, 'label': 1, 'score': 0.871716320514679, 'n_points': 121}
# n points: 198  {'box': tensor([14.9004, -2.9341,  1.8150], device='cuda:0'), 'dim': tensor([6.9870, 2.9049, 3.0383], device='cuda:0'), 'distance': 0.12, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 5.73, 'label': 1, 'score': 0.8216344118118286, 'n_points': 198}
# n points: 173  {'box': tensor([14.8866, -3.0252,  1.0864], device='cuda:0'), 'dim': tensor([4.4477, 2.0458, 1.7878], device='cuda:0'), 'distance': 0.1, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.15, 'label': 1, 'score': 0.9175787568092346, 'n_points': 173}
# n points: 138  {'box': tensor([14.9151, -3.0397,  1.0799], device='cuda:0'), 'dim': tensor([4.5022, 2.0537, 1.7878], device='cuda:0'), 'distance': 0.07, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.42, 'label': 1, 'score': 0.9124237895011902, 'n_points': 138}
# n points: 116  {'box': tensor([14.8532, -3.0013,  0.9772], device='cuda:0'), 'dim': tensor([4.4218, 2.0471, 1.7386], device='cuda:0'), 'distance': 0.14, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.38, 'label': 1, 'score': 0.9071376919746399, 'n_points': 116}
# NO PROPOSALS FOUND FOR TRACE WITH 156
# n points: 100  {'box': tensor([14.9889, -2.9169,  0.9209], device='cuda:0'), 'dim': tensor([4.4450, 1.9949, 1.4954], device='cuda:0'), 'distance': 0.03, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.96, 'label': 1, 'score': 0.8556554317474365, 'n_points': 100}
# n points: 147  {'box': tensor([15.0064, -2.9401,  0.9283], device='cuda:0'), 'dim': tensor([4.4390, 1.9975, 1.5354], device='cuda:0'), 'distance': 0.01, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 2.6, 'label': 1, 'score': 0.8708885312080383, 'n_points': 147}
# n points: 181  {'box': tensor([14.9007, -2.8479,  0.8164], device='cuda:0'), 'dim': tensor([4.6478, 2.0007, 1.4557], device='cuda:0'), 'distance': 0.12, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.79, 'label': 1, 'score': 0.9346674084663391, 'n_points': 181}
# n points: 120  {'box': tensor([14.9067, -2.8737,  0.8981], device='cuda:0'), 'dim': tensor([4.6604, 2.0508, 1.5452], device='cuda:0'), 'distance': 0.11, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.55, 'label': 1, 'score': 0.926840603351593, 'n_points': 120}
# n points: 156  {'box': tensor([15.0427, -3.0998,  0.9720], device='cuda:0'), 'dim': tensor([4.3905, 2.0065, 1.5403], device='cuda:0'), 'distance': 0.06, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 3.24, 'label': 1, 'score': 0.8458656072616577, 'n_points': 156}
# n points: 105  {'box': tensor([14.9417, -2.8829,  0.9667], device='cuda:0'), 'dim': tensor([4.7444, 2.0758, 1.5726], device='cuda:0'), 'distance': 0.08, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.17, 'label': 1, 'score': 0.9157775044441223, 'n_points': 105}
# NO PROPOSALS FOUND FOR TRACE WITH 158
# n points: 101  {'box': tensor([14.7859, -2.9371,  1.1613], device='cuda:0'), 'dim': tensor([4.7119, 2.1646, 1.7171], device='cuda:0'), 'distance': 0.21, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 5.35, 'label': 1, 'score': 0.8686628937721252, 'n_points': 101}
# n points: 138  {'box': tensor([14.9594, -2.9511,  1.2104], device='cuda:0'), 'dim': tensor([5.0558, 2.1939, 1.7016], device='cuda:0'), 'distance': 0.04, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 3.99, 'label': 1, 'score': 0.8960309624671936, 'n_points': 138}
# NO PROPOSALS FOUND FOR TRACE WITH 102
# NO PROPOSALS FOUND FOR TRACE WITH 160
# n points: 118  {'box': tensor([15.1415, -3.3704,  0.8695], device='cuda:0'), 'dim': tensor([4.2175, 1.9388, 2.0246], device='cuda:0'), 'distance': 0.22, 'cos_sim': tensor(0.9997, device='cuda:0'), 'volume': 7.69, 'label': 1, 'score': 0.19094586372375488, 'n_points': 118}
# NO PROPOSALS FOUND FOR TRACE WITH 124
# n points: 101  {'box': tensor([14.8576, -2.9582,  0.5504], device='cuda:0'), 'dim': tensor([4.1951, 1.9444, 1.6486], device='cuda:0'), 'distance': 0.14, 'cos_sim': tensor(0.9996, device='cuda:0'), 'volume': 5.37, 'label': 1, 'score': 0.12141656130552292, 'n_points': 101}
# n points: 142  {'box': tensor([15.0806, -3.2796,  0.9454], device='cuda:0'), 'dim': tensor([4.0836, 1.8497, 1.9223], device='cuda:0'), 'distance': 0.15, 'cos_sim': tensor(0.9997, device='cuda:0'), 'volume': 9.73, 'label': 1, 'score': 0.17987282574176788, 'n_points': 142}
# n points: 105  {'box': tensor([14.9796, -2.9469,  0.2783], device='cuda:0'), 'dim': tensor([3.0042, 2.2164, 1.4319], device='cuda:0'), 'distance': 0.03, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 1.46, 'label': 1, 'score': 0.1703292280435562, 'n_points': 105}
# NO PROPOSALS FOUND FOR TRACE WITH 149
# n points: 123  {'box': tensor([14.8614, -2.9625,  1.0097], device='cuda:0'), 'dim': tensor([4.3558, 2.0082, 1.6639], device='cuda:0'), 'distance': 0.14, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.66, 'label': 1, 'score': 0.8952158689498901, 'n_points': 123}
# NO PROPOSALS FOUND FOR TRACE WITH 129
# n points: 119  {'box': tensor([14.9781, -3.0061,  0.2944], device='cuda:0'), 'dim': tensor([3.7535, 2.1692, 1.3976], device='cuda:0'), 'distance': 0.02, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 3.3, 'label': 1, 'score': 0.2272966355085373, 'n_points': 119}
# n points: 157  {'box': tensor([15.0982, -2.9741,  0.9339], device='cuda:0'), 'dim': tensor([3.7061, 1.8826, 1.8599], device='cuda:0'), 'distance': 0.1, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 11.27, 'label': 1, 'score': 0.49787449836730957, 'n_points': 157}
# n points: 124  {'box': tensor([15.0177, -3.6257,  0.4091], device='cuda:0'), 'dim': tensor([1.2228, 1.2453, 1.4131], device='cuda:0'), 'distance': 0.16, 'cos_sim': tensor(0.9991, device='cuda:0'), 'volume': 5.93, 'label': 1, 'score': 0.1968061923980713, 'n_points': 124}
# NO PROPOSALS FOUND FOR TRACE WITH 172
# n points: 128  {'box': tensor([14.8387, -3.4949,  0.5835], device='cuda:0'), 'dim': tensor([3.5292, 2.2901, 1.5629], device='cuda:0'), 'distance': 0.04, 'cos_sim': tensor(0.9990, device='cuda:0'), 'volume': 4.55, 'label': 1, 'score': 0.169503316283226, 'n_points': 128}
# n points: 185  {'box': tensor([15.0805, -2.9676,  0.9157], device='cuda:0'), 'dim': tensor([3.8031, 1.9110, 1.9415], device='cuda:0'), 'distance': 0.08, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 10.13, 'label': 1, 'score': 0.6215872168540955, 'n_points': 185}
# n points: 147  {'box': tensor([14.8418, -3.4168,  0.5608], device='cuda:0'), 'dim': tensor([3.5961, 1.9811, 1.6301], device='cuda:0'), 'distance': 0.06, 'cos_sim': tensor(0.9992, device='cuda:0'), 'volume': 3.53, 'label': 1, 'score': 0.16949814558029175, 'n_points': 147}
# n points: 199  {'box': tensor([15.1265, -3.3269,  0.9093], device='cuda:0'), 'dim': tensor([4.1606, 1.9041, 1.9919], device='cuda:0'), 'distance': 0.2, 'cos_sim': tensor(0.9998, device='cuda:0'), 'volume': 8.46, 'label': 1, 'score': 0.24896864593029022, 'n_points': 199}
# n points: 138  {'box': tensor([14.9677, -3.0335,  0.4990], device='cuda:0'), 'dim': tensor([4.2164, 2.0093, 1.4459], device='cuda:0'), 'distance': 0.02, 'cos_sim': tensor(0.9997, device='cuda:0'), 'volume': 4.17, 'label': 1, 'score': 0.1154182031750679, 'n_points': 138}
# n points: 138  {'box': tensor([14.8383, -3.4306,  0.3705], device='cuda:0'), 'dim': tensor([4.0060, 2.2385, 1.6977], device='cuda:0'), 'distance': 0.06, 'cos_sim': tensor(0.9994, device='cuda:0'), 'volume': 7.15, 'label': 1, 'score': 0.2059255987405777, 'n_points': 138}
# n points: 166  {'box': tensor([14.8896, -3.4648,  0.4665], device='cuda:0'), 'dim': tensor([3.0475, 1.8983, 1.5296], device='cuda:0'), 'distance': 0.0, 'cos_sim': tensor(0.9993, device='cuda:0'), 'volume': 0.77, 'label': 1, 'score': 0.1934369057416916, 'n_points': 166}
# n points: 196  {'box': tensor([14.9761, -2.9096,  0.9640], device='cuda:0'), 'dim': tensor([4.5551, 2.0509, 1.6346], device='cuda:0'), 'distance': 0.04, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.54, 'label': 1, 'score': 0.9073953032493591, 'n_points': 196}
# n points: 180  {'box': tensor([14.8456, -3.3456,  0.4990], device='cuda:0'), 'dim': tensor([3.8898, 2.2925, 1.5780], device='cuda:0'), 'distance': 0.07, 'cos_sim': tensor(0.9996, device='cuda:0'), 'volume': 5.99, 'label': 1, 'score': 0.18045778572559357, 'n_points': 180}
# n points: 198  {'box': tensor([14.7815, -2.9197,  1.8075], device='cuda:0'), 'dim': tensor([7.0176, 2.8772, 3.3150], device='cuda:0'), 'distance': 0.19, 'cos_sim': tensor(0.9997, device='cuda:0'), 'volume': 0.46, 'label': 1, 'score': 0.7721511125564575, 'n_points': 198}
# NO PROPOSALS FOUND FOR TRACE WITH 109
# NO PROPOSALS FOUND FOR TRACE WITH 174
# n points: 106  {'box': tensor([14.8609, -3.0897,  1.1558], device='cuda:0'), 'dim': tensor([4.5612, 2.0998, 1.6311], device='cuda:0'), 'distance': 0.13, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 0.05, 'label': 1, 'score': 0.8917779922485352, 'n_points': 106}
# NO PROPOSALS FOUND FOR TRACE WITH 123
# n points: 112  {'box': tensor([14.8265, -3.0870,  1.1431], device='cuda:0'), 'dim': tensor([4.5295, 2.0587, 1.5520], device='cuda:0'), 'distance': 0.16, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 1.1, 'label': 1, 'score': 0.8974170684814453, 'n_points': 112}
# NO PROPOSALS FOUND FOR TRACE WITH 136
# n points: 182  {'box': tensor([14.8280, -3.0469,  1.0560], device='cuda:0'), 'dim': tensor([5.0230, 2.1884, 1.8385], device='cuda:0'), 'distance': 0.15, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 2.66, 'label': 1, 'score': 0.9238734245300293, 'n_points': 182}
# n points: 135  {'box': tensor([14.9457, -3.0243,  1.3461], device='cuda:0'), 'dim': tensor([4.6882, 2.1262, 1.6704], device='cuda:0'), 'distance': 0.05, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.08, 'label': 1, 'score': 0.8940592408180237, 'n_points': 135}
# NO PROPOSALS FOUND FOR TRACE WITH 147
# n points: 169  {'box': tensor([14.8121, -3.0061,  1.0940], device='cuda:0'), 'dim': tensor([5.0357, 2.2519, 1.9124], device='cuda:0'), 'distance': 0.17, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 1.18, 'label': 1, 'score': 0.9120315313339233, 'n_points': 169}
# n points: 153  {'box': tensor([14.8942, -3.0152,  1.4091], device='cuda:0'), 'dim': tensor([4.5751, 2.0985, 1.6492], device='cuda:0'), 'distance': 0.11, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.26, 'label': 1, 'score': 0.8836032152175903, 'n_points': 153}
# NO PROPOSALS FOUND FOR TRACE WITH 136
# NO PROPOSALS FOUND FOR TRACE WITH 160
# NO PROPOSALS FOUND FOR TRACE WITH 159
# n points: 192  {'box': tensor([14.8093, -3.0582,  1.0557], device='cuda:0'), 'dim': tensor([4.5325, 2.0683, 1.5373], device='cuda:0'), 'distance': 0.18, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 1.16, 'label': 1, 'score': 0.9098636507987976, 'n_points': 192}
# n points: 173  {'box': tensor([15.0605, -2.9207,  0.3193], device='cuda:0'), 'dim': tensor([5.4334, 2.2875, 1.9619], device='cuda:0'), 'distance': 0.05, 'cos_sim': tensor(0.9998, device='cuda:0'), 'volume': 6.26, 'label': 1, 'score': 0.8500257134437561, 'n_points': 173}
# NO PROPOSALS FOUND FOR TRACE WITH 173
# n points: 136  {'box': tensor([14.8726, -2.9611,  1.4635], device='cuda:0'), 'dim': tensor([5.0664, 2.2661, 1.9223], device='cuda:0'), 'distance': 0.13, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.8, 'label': 1, 'score': 0.9117099046707153, 'n_points': 136}
# n points: 171  {'box': tensor([15.0032, -2.9533, -0.1297], device='cuda:0'), 'dim': tensor([5.4727, 2.3126, 2.1187], device='cuda:0'), 'distance': 0.01, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 3.83, 'label': 1, 'score': 0.9249784350395203, 'n_points': 171}
# NO PROPOSALS FOUND FOR TRACE WITH 188
# n points: 107  {'box': tensor([14.8879, -2.9768,  1.3415], device='cuda:0'), 'dim': tensor([5.0691, 2.2744, 1.9027], device='cuda:0'), 'distance': 0.1, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 0.93, 'label': 1, 'score': 0.9092451930046082, 'n_points': 107}
# n points: 101  {'box': tensor([14.9925, -2.9743,  0.0390], device='cuda:0'), 'dim': tensor([4.5932, 2.1531, 1.6661], device='cuda:0'), 'distance': 0.01, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 7.04, 'label': 1, 'score': 0.15483218431472778, 'n_points': 101}
# n points: 196  {'box': tensor([15.0451, -3.0104,  0.0642], device='cuda:0'), 'dim': tensor([5.3051, 2.2823, 2.1559], device='cuda:0'), 'distance': 0.05, 'cos_sim': tensor(1.0000, device='cuda:0'), 'volume': 4.55, 'label': 1, 'score': 0.846491813659668, 'n_points': 196}
# n points: 106  {'box': tensor([14.7763, -2.9342,  1.1097], device='cuda:0'), 'dim': tensor([5.0105, 2.2486, 1.8960], device='cuda:0'), 'distance': 0.22, 'cos_sim': tensor(0.9999, device='cuda:0'), 'volume': 1.5, 'label': 1, 'score': 0.9229536056518555, 'n_points': 106}
# n points: 120  {'box': tensor([14.8293, -2.6266,  0.4754], device='cuda:0'), 'dim': tensor([4.0962, 1.9195, 1.5060], device='cuda:0'), 'distance': 0.23, 'cos_sim': tensor(0.9997, device='cuda:0'), 'volume': 11.68, 'label': 1, 'score': 0.2441311478614807, 'n_points': 120}
# n points: 146  {'box': tensor([14.8932, -3.5380,  0.7238], device='cuda:0'), 'dim': tensor([3.6445, 1.8453, 1.4412], device='cuda:0'), 'distance': 0.02, 'cos_sim': tensor(0.9993, device='cuda:0'), 'volume': 13.83, 'label': 1, 'score': 0.2839980125427246, 'n_points': 146}
# n points: 155  {'box': tensor([15.0720, -2.6272,  0.7709], device='cuda:0'), 'dim': tensor([4.2190, 1.9855, 1.4650], device='cuda:0'), 'distance': 0.01, 'cos_sim': tensor(0.9997, device='cuda:0'), 'volume': 11.25, 'label': 1, 'score': 0.47354429960250854, 'n_points': 155}
# n points: 145  {'box': tensor([14.9765, -2.7073,  0.7400], device='cuda:0'), 'dim': tensor([4.1144, 1.9554, 1.4486], device='cuda:0'), 'distance': 0.07, 'cos_sim': tensor(0.9998, device='cuda:0'), 'volume': 11.87, 'label': 1, 'score': 0.39021116495132446, 'n_points': 145}

# %%
# # Open a file in write-binary mode ('wb') and use pickle.dump()
# with open('spoof_data_bigger_trace.pkl', 'wb') as pkl_file:
#     pickle.dump(spoof_data, pkl_file)
# with open('failed_spoof_bigger_trace.pkl', 'wb') as pkl_file:
#     pickle.dump(failed_attempts, pkl_file)

# %%
len(spoof_data)
# Out:
# 194

# %%
spoof_data = spoof_data_smaller + spoof_data_bigger
npoints = [item['n_points'] for item in spoof_data]
distances = [item['distance'] for item in spoof_data]
volumes = [item['volume'] for item in spoof_data]
labels = [item['label'] for item in spoof_data]
scores= [item['score'] for item in spoof_data]

# %%
# Open a file in write-binary mode ('wb') and use pickle.dump()
import pickle
with open('spoof_data_cp_sf.pkl', 'wb') as pkl_file:
    pickle.dump(spoof_data, pkl_file)

# %%
fig, ax = plt.subplots()

sc = ax.scatter(
    npoints,
    scores,
    c=labels,
    alpha=0.7
)

ax.set_xlabel("Injected points")
ax.set_ylabel("Confidence Score")
ax.set_title("CenterPoint Single-Frame")
ax.set_ylim(0, 1)

# Build legend using the SAME colormap + normalization
unique_labels = np.unique(labels)
class_names = {1: "Vehicle", 2: "Pedestrian", 3: "Cyclist"}

handles = [
    plt.Line2D(
        [0], [0],
        marker='o',
        linestyle='',
        markersize=8,
        markerfacecolor=sc.cmap(sc.norm(l)),
        markeredgecolor='none',
        label=class_names[l]
    )
    for l in unique_labels
]

ax.legend(handles=handles)
plt.show()
fig.savefig('CPSF_score.png')

# %%
fig, ax = plt.subplots()

sc = ax.scatter(
    npoints,
    distances,
    c=labels,
    alpha=0.7
)


ax.set_xlabel("Injected points")
ax.set_ylabel("Difference in centroid position (|predicted - actual|) (m)")
ax.set_title("CenterPoint Single-Frame")
ax.set_ylim(0, 2.3)


ax.legend(handles=handles)
plt.show()
fig.savefig('CPSF_distance.png')

# %%
fig, ax = plt.subplots()

sc = ax.scatter(
    npoints,
    volumes,
    c=labels,
    alpha=0.7
)

ax.set_xlabel("Injected points")
ax.set_ylabel("Difference in bounding box volume (|predicted - actual|) (m^3)")
ax.set_title("CenterPoint Single-Frame")


ax.legend(handles=handles)
plt.show()
fig.savefig('CPSF_volume.png')

# %%
num_misclassified = 0
for label in labels:
    if label != 1: num_misclassified+=1
print((len(labels) - num_misclassified) / len(labels))
# Out:
# 1.0

# %%
confident_threshold = 0.5
strong_threshold = 0.7
confident = []
strong = []
bins = []
classification = []
for i in range(3, 20):
    npoints =  [element for element in spoof_data if element['n_points'] >= (i*10) and element['n_points'] <= (i+1)*10]
    confident_bin = sum(1 for element in npoints if element['score']>confident_threshold) / len(npoints)
    strong_bin = sum(1 for element in npoints if element['score']>strong_threshold) / len(npoints)
    correctly_classified = sum(1 for element in npoints if element['label']==1) / len(npoints) 
    confident.append(confident_bin)
    strong.append(strong_bin)
    classification.append(correctly_classified)
    bins.append(f"{i*10} - {(i+1)*10}")

# %%
plt.figure(figsize=(8, 5))

# Plot 'Confident' line with dots
plt.plot(bins, confident, marker='o', linestyle='-', label='>0.5', linewidth=2)

# Plot 'Strong' line with dots
plt.plot(bins, strong, marker='o', linestyle='-', label='>0.7', linewidth=2)


# Customization
plt.title('Proportion of Scores Above Confidence Thresholds by n_points Bin (CenterPoint Single-Frame)', fontsize=14)
plt.xlabel('n_points Range', fontsize=14)
plt.ylabel('Proportion', fontsize=14)
plt.xticks(rotation=45) # Rotate bin labels for better readabilit
plt.legend()

# Add background grid
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))

# Plot 'Confident' line with dots
plt.plot(bins, classification, marker='o', linestyle='-', linewidth=2)

# Plot 'Strong' line with dots

# Customization
plt.title('Proportion of objects correctly classified (CenterPoint Single-Frame)', fontsize=14)
plt.xlabel('n_points Range', fontsize=14)
plt.ylabel('Proportion', fontsize=14)
plt.xticks(rotation=45) # Rotate bin labels for better readabilit
plt.ylim(0, 1.1)

# Add background grid
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
spoof_data
# Out:
# [{'box': tensor([14.8485, -3.0524,  0.9263], device='cuda:0'),
#   'dim': tensor([4.6562, 2.0401, 1.5171], device='cuda:0'),
#   'distance': 0.14,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.6,
#   'label': 1,
#   'score': 0.9036597013473511,
#   'n_points': 93},
#  {'box': tensor([14.8898, -3.0887,  1.0958], device='cuda:0'),
#   'dim': tensor([4.7492, 2.1275, 1.7325], device='cuda:0'),
#   'distance': 0.08,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 3.7,
#   'label': 1,
#   'score': 0.8171117305755615,
#   'n_points': 34},
#  {'box': tensor([14.7943, -3.3270,  0.9620], device='cuda:0'),
#   'dim': tensor([4.5103, 2.0625, 1.5568], device='cuda:0'),
#   'distance': 0.13,
#   'cos_sim': tensor(0.9997, device='cuda:0'),
#   'volume': 0.68,
#   'label': 1,
#   'score': 0.5257932543754578,
#   'n_points': 31},
#  {'box': tensor([15.0289, -2.8826,  0.7650], device='cuda:0'),
#   'dim': tensor([4.3565, 2.0260, 1.4499], device='cuda:0'),
#   'distance': 0.01,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.2,
#   'label': 1,
#   'score': 0.7208812236785889,
#   'n_points': 32},
#  {'box': tensor([14.8120, -3.0710,  1.0358], device='cuda:0'),
#   'dim': tensor([4.4896, 2.0746, 1.6230], device='cuda:0'),
#   'distance': 0.17,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.31,
#   'label': 1,
#   'score': 0.8413299322128296,
#   'n_points': 53},
#  {'box': tensor([14.9740, -2.9937,  0.8483], device='cuda:0'),
#   'dim': tensor([4.2413, 1.9956, 1.4423], device='cuda:0'),
#   'distance': 0.03,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.61,
#   'label': 1,
#   'score': 0.7559768557548523,
#   'n_points': 42},
#  {'box': tensor([14.8524, -3.0118,  1.0977], device='cuda:0'),
#   'dim': tensor([4.6621, 2.1184, 1.6891], device='cuda:0'),
#   'distance': 0.13,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 2.88,
#   'label': 1,
#   'score': 0.6751389503479004,
#   'n_points': 39},
#  {'box': tensor([15.0166, -3.0057,  0.8879], device='cuda:0'),
#   'dim': tensor([4.2858, 2.0153, 1.4318], device='cuda:0'),
#   'distance': 0.01,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.77,
#   'label': 1,
#   'score': 0.781710147857666,
#   'n_points': 44},
#  {'box': tensor([14.8098, -3.1049,  1.1719], device='cuda:0'),
#   'dim': tensor([4.5313, 2.0652, 1.6639], device='cuda:0'),
#   'distance': 0.16,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.76,
#   'label': 1,
#   'score': 0.696364164352417,
#   'n_points': 36},
#  {'box': tensor([14.9153, -3.0554,  0.8110], device='cuda:0'),
#   'dim': tensor([4.0741, 1.9479, 1.4246], device='cuda:0'),
#   'distance': 0.07,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.29,
#   'label': 1,
#   'score': 0.8295958638191223,
#   'n_points': 49},
#  {'box': tensor([14.7145, -3.0371,  1.2687], device='cuda:0'),
#   'dim': tensor([4.4950, 2.0924, 1.7815], device='cuda:0'),
#   'distance': 0.27,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 2.95,
#   'label': 1,
#   'score': 0.6838102340698242,
#   'n_points': 32},
#  {'box': tensor([14.9905, -3.0400,  0.7274], device='cuda:0'),
#   'dim': tensor([4.1037, 1.9303, 1.3248], device='cuda:0'),
#   'distance': 0.0,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.1,
#   'label': 1,
#   'score': 0.702273428440094,
#   'n_points': 60},
#  {'box': tensor([14.9472, -3.0307,  0.7490], device='cuda:0'),
#   'dim': tensor([4.2180, 1.9796, 1.3806], device='cuda:0'),
#   'distance': 0.04,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.07,
#   'label': 1,
#   'score': 0.8198643922805786,
#   'n_points': 71},
#  {'box': tensor([14.8980, -3.0395,  0.9040], device='cuda:0'),
#   'dim': tensor([4.4951, 1.9934, 1.5260], device='cuda:0'),
#   'distance': 0.09,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.52,
#   'label': 1,
#   'score': 0.7245352268218994,
#   'n_points': 65},
#  {'box': tensor([15.0388, -2.9671,  0.6775], device='cuda:0'),
#   'dim': tensor([4.2639, 1.9684, 1.3347], device='cuda:0'),
#   'distance': 0.03,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.4,
#   'label': 1,
#   'score': 0.8401054739952087,
#   'n_points': 72},
#  {'box': tensor([14.9641, -3.0383,  0.9064], device='cuda:0'),
#   'dim': tensor([4.5669, 2.0386, 1.5111], device='cuda:0'),
#   'distance': 0.03,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.92,
#   'label': 1,
#   'score': 0.8191718459129333,
#   'n_points': 82},
#  {'box': tensor([14.9519, -3.0430,  0.6725], device='cuda:0'),
#   'dim': tensor([4.0631, 1.9334, 1.3601], device='cuda:0'),
#   'distance': 0.03,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.91,
#   'label': 1,
#   'score': 0.8625239729881287,
#   'n_points': 91},
#  {'box': tensor([14.9187, -3.0668,  0.9247], device='cuda:0'),
#   'dim': tensor([4.5879, 2.0486, 1.5311], device='cuda:0'),
#   'distance': 0.06,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.24,
#   'label': 1,
#   'score': 0.8159064054489136,
#   'n_points': 68},
#  {'box': tensor([14.9065, -3.0587,  0.9224], device='cuda:0'),
#   'dim': tensor([4.5011, 2.0336, 1.5307], device='cuda:0'),
#   'distance': 0.08,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.86,
#   'label': 1,
#   'score': 0.8163022994995117,
#   'n_points': 58},
#  {'box': tensor([15.3564, -3.0585,  1.5429], device='cuda:0'),
#   'dim': tensor([7.3709, 2.9504, 2.6361], device='cuda:0'),
#   'distance': 0.36,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 3.61,
#   'label': 1,
#   'score': 0.7751876711845398,
#   'n_points': 97},
#  {'box': tensor([14.9403, -2.9790,  0.7655], device='cuda:0'),
#   'dim': tensor([4.4641, 1.9703, 1.4256], device='cuda:0'),
#   'distance': 0.06,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 3.58,
#   'label': 1,
#   'score': 0.28277599811553955,
#   'n_points': 15},
#  {'box': tensor([14.9317, -3.0996,  1.0236], device='cuda:0'),
#   'dim': tensor([4.4929, 2.0447, 1.5665], device='cuda:0'),
#   'distance': 0.04,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.24,
#   'label': 1,
#   'score': 0.8154489994049072,
#   'n_points': 47},
#  {'box': tensor([15.3900, -3.0351,  1.6407], device='cuda:0'),
#   'dim': tensor([7.4205, 3.0519, 2.8536], device='cuda:0'),
#   'distance': 0.39,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 10.91,
#   'label': 1,
#   'score': 0.7428627014160156,
#   'n_points': 95},
#  {'box': tensor([14.8709, -2.9815,  1.0783], device='cuda:0'),
#   'dim': tensor([4.4084, 2.0035, 1.5829], device='cuda:0'),
#   'distance': 0.13,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.83,
#   'label': 1,
#   'score': 0.8279780745506287,
#   'n_points': 44},
#  {'box': tensor([14.9580, -3.0102,  0.9131], device='cuda:0'),
#   'dim': tensor([4.4353, 1.9937, 1.5065], device='cuda:0'),
#   'distance': 0.03,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.19,
#   'label': 1,
#   'score': 0.9103626012802124,
#   'n_points': 85},
#  {'box': tensor([14.8971, -2.8827,  1.6169], device='cuda:0'),
#   'dim': tensor([6.8119, 3.1047, 2.9816], device='cuda:0'),
#   'distance': 0.13,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 9.34,
#   'label': 1,
#   'score': 0.448916494846344,
#   'n_points': 71},
#  {'box': tensor([14.9195, -2.8316,  0.6661], device='cuda:0'),
#   'dim': tensor([4.3182, 1.9401, 1.3937], device='cuda:0'),
#   'distance': 0.11,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 4.44,
#   'label': 1,
#   'score': 0.47804880142211914,
#   'n_points': 46},
#  {'box': tensor([14.9047, -2.9769,  1.0613], device='cuda:0'),
#   'dim': tensor([4.4683, 2.0561, 1.7082], device='cuda:0'),
#   'distance': 0.1,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 2.54,
#   'label': 1,
#   'score': 0.7540950775146484,
#   'n_points': 37},
#  {'box': tensor([14.9381, -3.0145,  0.8822], device='cuda:0'),
#   'dim': tensor([4.4820, 2.0122, 1.4778], device='cuda:0'),
#   'distance': 0.05,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.2,
#   'label': 1,
#   'score': 0.8794938325881958,
#   'n_points': 55},
#  {'box': tensor([15.4074, -2.0353,  1.5158], device='cuda:0'),
#   'dim': tensor([8.1416, 2.8920, 2.7015], device='cuda:0'),
#   'distance': 0.24,
#   'cos_sim': tensor(0.9978, device='cuda:0'),
#   'volume': 9.89,
#   'label': 1,
#   'score': 0.11527223885059357,
#   'n_points': 46},
#  {'box': tensor([14.9387, -2.9499,  0.6171], device='cuda:0'),
#   'dim': tensor([4.4622, 2.0416, 1.4603], device='cuda:0'),
#   'distance': 0.07,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 2.81,
#   'label': 1,
#   'score': 0.6973987817764282,
#   'n_points': 55},
#  {'box': tensor([14.9078, -3.2591,  1.0236], device='cuda:0'),
#   'dim': tensor([4.6490, 2.0940, 1.6419], device='cuda:0'),
#   'distance': 0.04,
#   'cos_sim': tensor(0.9998, device='cuda:0'),
#   'volume': 2.84,
#   'label': 1,
#   'score': 0.3286494314670563,
#   'n_points': 33},
#  {'box': tensor([14.9089, -3.0012,  0.8166], device='cuda:0'),
#   'dim': tensor([4.4248, 1.9847, 1.4703], device='cuda:0'),
#   'distance': 0.09,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.78,
#   'label': 1,
#   'score': 0.8710798025131226,
#   'n_points': 46},
#  {'box': tensor([14.5401, -2.1282,  1.3041], device='cuda:0'),
#   'dim': tensor([6.5103, 2.6951, 2.1987], device='cuda:0'),
#   'distance': 0.61,
#   'cos_sim': tensor(0.9986, device='cuda:0'),
#   'volume': 15.14,
#   'label': 1,
#   'score': 0.22870546579360962,
#   'n_points': 18},
#  {'box': tensor([15.0671, -2.9465,  0.6519], device='cuda:0'),
#   'dim': tensor([4.6411, 2.0716, 1.4120], device='cuda:0'),
#   'distance': 0.06,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 2.54,
#   'label': 1,
#   'score': 0.8017708659172058,
#   'n_points': 83},
#  {'box': tensor([15.0083, -3.0958,  0.9536], device='cuda:0'),
#   'dim': tensor([4.5294, 2.0752, 1.5764], device='cuda:0'),
#   'distance': 0.03,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 2.69,
#   'label': 1,
#   'score': 0.7798340916633606,
#   'n_points': 36},
#  {'box': tensor([15.0157, -3.1301,  1.0966], device='cuda:0'),
#   'dim': tensor([4.4661, 2.0438, 1.6111], device='cuda:0'),
#   'distance': 0.05,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 2.58,
#   'label': 1,
#   'score': 0.7135154604911804,
#   'n_points': 39},
#  {'box': tensor([14.9824, -3.0805,  1.0282], device='cuda:0'),
#   'dim': tensor([4.4000, 2.0394, 1.5564], device='cuda:0'),
#   'distance': 0.0,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.83,
#   'label': 1,
#   'score': 0.6925446391105652,
#   'n_points': 24},
#  {'box': tensor([15.0462, -3.0246,  1.1439], device='cuda:0'),
#   'dim': tensor([4.4877, 2.0740, 1.7456], device='cuda:0'),
#   'distance': 0.06,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 4.12,
#   'label': 1,
#   'score': 0.5208919644355774,
#   'n_points': 18},
#  {'box': tensor([14.8990, -3.3634,  0.6392], device='cuda:0'),
#   'dim': tensor([4.1985, 1.8664, 1.4106], device='cuda:0'),
#   'distance': 0.02,
#   'cos_sim': tensor(0.9997, device='cuda:0'),
#   'volume': 4.27,
#   'label': 1,
#   'score': 0.26230737566947937,
#   'n_points': 38},
#  {'box': tensor([15.0003, -2.9122,  1.0919], device='cuda:0'),
#   'dim': tensor([4.4226, 2.0572, 1.6678], device='cuda:0'),
#   'distance': 0.01,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 3.04,
#   'label': 1,
#   'score': 0.5810723304748535,
#   'n_points': 18},
#  {'box': tensor([14.9579, -3.4161,  0.7066], device='cuda:0'),
#   'dim': tensor([4.3699, 1.9418, 1.4666], device='cuda:0'),
#   'distance': 0.05,
#   'cos_sim': tensor(0.9996, device='cuda:0'),
#   'volume': 2.88,
#   'label': 1,
#   'score': 0.23929765820503235,
#   'n_points': 58},
#  {'box': tensor([15.0074, -2.9872,  1.0702], device='cuda:0'),
#   'dim': tensor([4.4365, 2.0513, 1.6420], device='cuda:0'),
#   'distance': 0.01,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 2.81,
#   'label': 1,
#   'score': 0.534395158290863,
#   'n_points': 14},
#  {'box': tensor([15.0303, -3.0373,  0.8128], device='cuda:0'),
#   'dim': tensor([4.6860, 2.0917, 1.4937], device='cuda:0'),
#   'distance': 0.04,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.68,
#   'label': 1,
#   'score': 0.6897097229957581,
#   'n_points': 69},
#  {'box': tensor([14.9578, -3.0085,  0.7840], device='cuda:0'),
#   'dim': tensor([4.5756, 2.0681, 1.4727], device='cuda:0'),
#   'distance': 0.04,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.39,
#   'label': 1,
#   'score': 0.812421977519989,
#   'n_points': 86},
#  {'box': tensor([15.0313, -3.0519,  0.7915], device='cuda:0'),
#   'dim': tensor([4.7132, 2.0838, 1.4269], device='cuda:0'),
#   'distance': 0.04,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.31,
#   'label': 1,
#   'score': 0.8443704843521118,
#   'n_points': 80},
#  {'box': tensor([14.8902, -2.9665,  0.9845], device='cuda:0'),
#   'dim': tensor([4.6266, 2.0955, 1.5658], device='cuda:0'),
#   'distance': 0.11,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.44,
#   'label': 1,
#   'score': 0.9120312333106995,
#   'n_points': 90},
#  {'box': tensor([14.8646, -3.0235,  1.0664], device='cuda:0'),
#   'dim': tensor([4.6133, 2.0955, 1.6561], device='cuda:0'),
#   'distance': 0.13,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.39,
#   'label': 1,
#   'score': 0.8660647869110107,
#   'n_points': 73},
#  {'box': tensor([14.8946, -3.0406,  1.0447], device='cuda:0'),
#   'dim': tensor([4.6528, 2.0816, 1.5486], device='cuda:0'),
#   'distance': 0.1,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.63,
#   'label': 1,
#   'score': 0.9076248407363892,
#   'n_points': 80},
#  {'box': tensor([14.8689, -2.9578,  1.0577], device='cuda:0'),
#   'dim': tensor([4.5915, 2.1471, 1.7385], device='cuda:0'),
#   'distance': 0.15,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.52,
#   'label': 1,
#   'score': 0.7660102844238281,
#   'n_points': 59},
#  {'box': tensor([14.6132, -2.9676,  2.1096], device='cuda:0'),
#   'dim': tensor([7.6312, 2.9004, 2.7953], device='cuda:0'),
#   'distance': 0.35,
#   'cos_sim': tensor(0.9998, device='cuda:0'),
#   'volume': 5.53,
#   'label': 1,
#   'score': 0.2663207948207855,
#   'n_points': 75},
#  {'box': tensor([14.8106, -2.9225,  1.0611], device='cuda:0'),
#   'dim': tensor([4.5146, 2.0930, 1.7310], device='cuda:0'),
#   'distance': 0.21,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.73,
#   'label': 1,
#   'score': 0.7969616055488586,
#   'n_points': 42},
#  {'box': tensor([14.8215, -3.0445,  1.1902], device='cuda:0'),
#   'dim': tensor([4.5224, 2.0834, 1.7937], device='cuda:0'),
#   'distance': 0.16,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.28,
#   'label': 1,
#   'score': 0.760691225528717,
#   'n_points': 39},
#  {'box': tensor([15.0507, -3.0738,  0.8765], device='cuda:0'),
#   'dim': tensor([4.2366, 1.9865, 1.5819], device='cuda:0'),
#   'distance': 0.06,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.72,
#   'label': 1,
#   'score': 0.6087772846221924,
#   'n_points': 58},
#  {'box': tensor([14.8937, -3.2664,  1.0509], device='cuda:0'),
#   'dim': tensor([4.3729, 2.0191, 1.6005], device='cuda:0'),
#   'distance': 0.08,
#   'cos_sim': tensor(0.9996, device='cuda:0'),
#   'volume': 2.09,
#   'label': 1,
#   'score': 0.1684524416923523,
#   'n_points': 24},
#  {'box': tensor([14.9956, -2.9881,  0.8478], device='cuda:0'),
#   'dim': tensor([4.2858, 1.9939, 1.5169], device='cuda:0'),
#   'distance': 0.01,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.37,
#   'label': 1,
#   'score': 0.8555490374565125,
#   'n_points': 96},
#  {'box': tensor([14.9345, -3.2816,  1.0603], device='cuda:0'),
#   'dim': tensor([4.4554, 2.0477, 1.6260], device='cuda:0'),
#   'distance': 0.03,
#   'cos_sim': tensor(0.9996, device='cuda:0'),
#   'volume': 1.38,
#   'label': 1,
#   'score': 0.187826007604599,
#   'n_points': 19},
#  {'box': tensor([14.9767, -3.2285,  1.0781], device='cuda:0'),
#   'dim': tensor([4.3255, 2.0217, 1.5915], device='cuda:0'),
#   'distance': 0.0,
#   'cos_sim': tensor(0.9997, device='cuda:0'),
#   'volume': 2.3,
#   'label': 1,
#   'score': 0.23542089760303497,
#   'n_points': 28},
#  {'box': tensor([14.9835, -3.0132,  0.9350], device='cuda:0'),
#   'dim': tensor([4.2026, 1.9574, 1.5338], device='cuda:0'),
#   'distance': 0.02,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.02,
#   'label': 1,
#   'score': 0.8665068745613098,
#   'n_points': 94},
#  {'box': tensor([15.0967, -2.8744,  1.0231], device='cuda:0'),
#   'dim': tensor([4.3726, 1.9887, 1.6703], device='cuda:0'),
#   'distance': 0.04,
#   'cos_sim': tensor(0.9997, device='cuda:0'),
#   'volume': 1.69,
#   'label': 1,
#   'score': 0.27145758271217346,
#   'n_points': 13},
#  {'box': tensor([14.9670, -3.0400,  0.9226], device='cuda:0'),
#   'dim': tensor([4.3496, 2.0319, 1.5983], device='cuda:0'),
#   'distance': 0.03,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 2.53,
#   'label': 1,
#   'score': 0.8506235480308533,
#   'n_points': 77},
#  {'box': tensor([14.9734, -2.9678,  1.0092], device='cuda:0'),
#   'dim': tensor([4.3972, 2.0039, 1.5169], device='cuda:0'),
#   'distance': 0.05,
#   'cos_sim': tensor(0.9998, device='cuda:0'),
#   'volume': 2.85,
#   'label': 1,
#   'score': 0.7116753458976746,
#   'n_points': 32},
#  {'box': tensor([14.9816, -2.8651,  1.0659], device='cuda:0'),
#   'dim': tensor([4.5339, 2.0533, 1.7178], device='cuda:0'),
#   'distance': 0.08,
#   'cos_sim': tensor(0.9996, device='cuda:0'),
#   'volume': 0.82,
#   'label': 1,
#   'score': 0.1657821089029312,
#   'n_points': 9},
#  {'box': tensor([14.9217, -3.0028,  0.8237], device='cuda:0'),
#   'dim': tensor([4.2164, 1.9993, 1.4759], device='cuda:0'),
#   'distance': 0.08,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.85,
#   'label': 1,
#   'score': 0.8747630715370178,
#   'n_points': 66},
#  {'box': tensor([14.9684, -3.2253,  1.0777], device='cuda:0'),
#   'dim': tensor([4.2413, 2.0028, 1.6290], device='cuda:0'),
#   'distance': 0.0,
#   'cos_sim': tensor(0.9998, device='cuda:0'),
#   'volume': 2.38,
#   'label': 1,
#   'score': 0.14744031429290771,
#   'n_points': 43},
#  {'box': tensor([14.9940, -2.9162,  1.1351], device='cuda:0'),
#   'dim': tensor([4.5673, 2.1000, 1.7890], device='cuda:0'),
#   'distance': 0.04,
#   'cos_sim': tensor(0.9998, device='cuda:0'),
#   'volume': 0.35,
#   'label': 1,
#   'score': 0.7424291968345642,
#   'n_points': 28},
#  {'box': tensor([14.9344, -3.0186,  0.7939], device='cuda:0'),
#   'dim': tensor([4.2505, 2.0217, 1.4565], device='cuda:0'),
#   'distance': 0.07,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.92,
#   'label': 1,
#   'score': 0.8589616417884827,
#   'n_points': 57},
#  {'box': tensor([15.0185, -2.8879,  1.0440], device='cuda:0'),
#   'dim': tensor([4.4060, 2.0265, 1.5536], device='cuda:0'),
#   'distance': 0.02,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 2.35,
#   'label': 1,
#   'score': 0.7815943360328674,
#   'n_points': 47},
#  {'box': tensor([15.0772, -2.9809,  1.1725], device='cuda:0'),
#   'dim': tensor([4.5567, 2.1068, 1.8279], device='cuda:0'),
#   'distance': 0.05,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 0.74,
#   'label': 1,
#   'score': 0.6647648811340332,
#   'n_points': 33},
#  {'box': tensor([14.9185, -2.9998,  0.8943], device='cuda:0'),
#   'dim': tensor([4.1807, 2.0141, 1.5216], device='cuda:0'),
#   'distance': 0.08,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.22,
#   'label': 1,
#   'score': 0.8036422729492188,
#   'n_points': 45},
#  {'box': tensor([14.8572, -3.2807,  0.9843], device='cuda:0'),
#   'dim': tensor([4.4115, 2.0359, 1.7084], device='cuda:0'),
#   'distance': 0.08,
#   'cos_sim': tensor(0.9998, device='cuda:0'),
#   'volume': 0.77,
#   'label': 1,
#   'score': 0.7287358641624451,
#   'n_points': 49},
#  {'box': tensor([14.9767, -2.8637,  1.0121], device='cuda:0'),
#   'dim': tensor([4.3526, 1.9999, 1.4919], device='cuda:0'),
#   'distance': 0.06,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 3.23,
#   'label': 1,
#   'score': 0.8110672831535339,
#   'n_points': 71},
#  {'box': tensor([15.0500, -2.9314,  1.0801], device='cuda:0'),
#   'dim': tensor([4.5287, 2.0782, 1.7575], device='cuda:0'),
#   'distance': 0.02,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 0.27,
#   'label': 1,
#   'score': 0.6286397576332092,
#   'n_points': 26},
#  {'box': tensor([14.9542, -2.9953,  0.8213], device='cuda:0'),
#   'dim': tensor([4.2070, 1.9774, 1.4563], device='cuda:0'),
#   'distance': 0.05,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.52,
#   'label': 1,
#   'score': 0.8002322912216187,
#   'n_points': 33},
#  {'box': tensor([14.7950, -3.1080,  1.2031], device='cuda:0'),
#   'dim': tensor([4.8168, 2.1793, 1.7729], device='cuda:0'),
#   'distance': 0.19,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 4.26,
#   'label': 1,
#   'score': 0.6237379312515259,
#   'n_points': 33},
#  {'box': tensor([14.9368, -3.0301,  1.0121], device='cuda:0'),
#   'dim': tensor([4.5103, 2.0854, 1.7301], device='cuda:0'),
#   'distance': 0.05,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.16,
#   'label': 1,
#   'score': 0.8623558282852173,
#   'n_points': 80},
#  {'box': tensor([15.0099, -2.8960,  0.9491], device='cuda:0'),
#   'dim': tensor([4.5010, 2.0563, 1.5354], device='cuda:0'),
#   'distance': 0.02,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 2.01,
#   'label': 1,
#   'score': 0.8287619948387146,
#   'n_points': 81},
#  {'box': tensor([15.0437, -3.0640,  1.0741], device='cuda:0'),
#   'dim': tensor([4.4250, 2.0199, 1.5722], device='cuda:0'),
#   'distance': 0.05,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 2.75,
#   'label': 1,
#   'score': 0.7174019813537598,
#   'n_points': 23},
#  {'box': tensor([14.9852, -3.0066,  0.9105], device='cuda:0'),
#   'dim': tensor([4.2212, 1.9926, 1.5383], device='cuda:0'),
#   'distance': 0.01,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.34,
#   'label': 1,
#   'score': 0.8086203932762146,
#   'n_points': 42},
#  {'box': tensor([14.8370, -2.9735,  1.2019], device='cuda:0'),
#   'dim': tensor([4.9293, 2.2594, 1.8200], device='cuda:0'),
#   'distance': 0.17,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 2.6,
#   'label': 1,
#   'score': 0.8222823739051819,
#   'n_points': 43},
#  {'box': tensor([14.9109, -3.0107,  1.0587], device='cuda:0'),
#   'dim': tensor([4.5235, 2.0889, 1.8196], device='cuda:0'),
#   'distance': 0.07,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 1.08,
#   'label': 1,
#   'score': 0.7997778654098511,
#   'n_points': 59},
#  {'box': tensor([14.9820, -2.9153,  0.9149], device='cuda:0'),
#   'dim': tensor([4.4407, 2.0010, 1.5127], device='cuda:0'),
#   'distance': 0.04,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 2.78,
#   'label': 1,
#   'score': 0.8705664873123169,
#   'n_points': 100},
#  {'box': tensor([14.9485, -3.3856,  0.9527], device='cuda:0'),
#   'dim': tensor([2.7524, 1.5990, 1.6896], device='cuda:0'),
#   'distance': 0.02,
#   'cos_sim': tensor(0.9996, device='cuda:0'),
#   'volume': 9.37,
#   'label': 1,
#   'score': 0.1094842404127121,
#   'n_points': 7},
#  {'box': tensor([14.7872, -3.0342,  1.2112], device='cuda:0'),
#   'dim': tensor([4.8884, 2.2599, 1.8462], device='cuda:0'),
#   'distance': 0.2,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 2.47,
#   'label': 1,
#   'score': 0.8059560060501099,
#   'n_points': 31},
#  {'box': tensor([14.8689, -2.9871,  0.9025], device='cuda:0'),
#   'dim': tensor([4.4691, 2.0450, 1.5606], device='cuda:0'),
#   'distance': 0.13,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.85,
#   'label': 1,
#   'score': 0.7871885895729065,
#   'n_points': 55},
#  {'box': tensor([15.0325, -3.0656,  0.9245], device='cuda:0'),
#   'dim': tensor([4.4500, 2.0650, 1.5023], device='cuda:0'),
#   'distance': 0.03,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 3.0,
#   'label': 1,
#   'score': 0.6027510166168213,
#   'n_points': 14},
#  {'box': tensor([14.9088, -2.9237,  1.3336], device='cuda:0'),
#   'dim': tensor([4.9275, 2.2623, 1.8361], device='cuda:0'),
#   'distance': 0.1,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 2.4,
#   'label': 1,
#   'score': 0.7950950860977173,
#   'n_points': 52},
#  {'box': tensor([14.8981, -3.2618,  0.8759], device='cuda:0'),
#   'dim': tensor([4.6479, 2.1366, 1.6111], device='cuda:0'),
#   'distance': 0.04,
#   'cos_sim': tensor(0.9998, device='cuda:0'),
#   'volume': 0.12,
#   'label': 1,
#   'score': 0.14326323568820953,
#   'n_points': 33},
#  {'box': tensor([15.1002, -3.0675,  0.9904], device='cuda:0'),
#   'dim': tensor([4.4875, 2.0769, 1.5913], device='cuda:0'),
#   'distance': 0.1,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.98,
#   'label': 1,
#   'score': 0.7244198322296143,
#   'n_points': 44},
#  {'box': tensor([14.8718, -2.9745,  1.2533], device='cuda:0'),
#   'dim': tensor([4.9122, 2.2479, 1.8454], device='cuda:0'),
#   'distance': 0.13,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 2.49,
#   'label': 1,
#   'score': 0.8703523278236389,
#   'n_points': 72},
#  {'box': tensor([14.9207, -3.0107,  0.9481], device='cuda:0'),
#   'dim': tensor([4.4601, 2.0503, 1.6293], device='cuda:0'),
#   'distance': 0.07,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.21,
#   'label': 1,
#   'score': 0.7554458379745483,
#   'n_points': 46},
#  {'box': tensor([15.0037, -3.0385,  0.9634], device='cuda:0'),
#   'dim': tensor([4.5059, 2.0341, 1.4716], device='cuda:0'),
#   'distance': 0.0,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 3.32,
#   'label': 1,
#   'score': 0.8172352313995361,
#   'n_points': 40},
#  {'box': tensor([14.8685, -2.9750,  1.1969], device='cuda:0'),
#   'dim': tensor([4.7255, 2.1839, 1.7814], device='cuda:0'),
#   'distance': 0.12,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 4.48,
#   'label': 1,
#   'score': 0.8795047402381897,
#   'n_points': 82},
#  {'box': tensor([14.9525, -3.0427,  1.0413], device='cuda:0'),
#   'dim': tensor([4.4374, 2.0577, 1.6794], device='cuda:0'),
#   'distance': 0.04,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.78,
#   'label': 1,
#   'score': 0.6921233534812927,
#   'n_points': 41},
#  {'box': tensor([14.8720, -3.0365,  1.0761], device='cuda:0'),
#   'dim': tensor([4.7460, 2.1486, 1.7095], device='cuda:0'),
#   'distance': 0.11,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 5.43,
#   'label': 1,
#   'score': 0.888138473033905,
#   'n_points': 91},
#  {'box': tensor([14.9989, -2.9881,  1.1484], device='cuda:0'),
#   'dim': tensor([4.5699, 2.1285, 1.8323], device='cuda:0'),
#   'distance': 0.0,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.71,
#   'label': 1,
#   'score': 0.6782200336456299,
#   'n_points': 32},
#  {'box': tensor([15.0179, -2.8968,  0.8742], device='cuda:0'),
#   'dim': tensor([4.7308, 2.1107, 1.5151], device='cuda:0'),
#   'distance': 0.0,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.19,
#   'label': 1,
#   'score': 0.8561780452728271,
#   'n_points': 76},
#  {'box': tensor([14.7299, -3.0475,  1.2470], device='cuda:0'),
#   'dim': tensor([4.7806, 2.2288, 1.8559], device='cuda:0'),
#   'distance': 0.25,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 3.09,
#   'label': 1,
#   'score': 0.8907461166381836,
#   'n_points': 91},
#  {'box': tensor([14.9037, -3.2456,  0.8338], device='cuda:0'),
#   'dim': tensor([4.5568, 2.0703, 1.5173], device='cuda:0'),
#   'distance': 0.04,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 1.01,
#   'label': 1,
#   'score': 0.16055504977703094,
#   'n_points': 56},
#  {'box': tensor([14.9645, -3.2065,  0.8920], device='cuda:0'),
#   'dim': tensor([4.1410, 2.0244, 1.5827], device='cuda:0'),
#   'distance': 0.01,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 2.05,
#   'label': 1,
#   'score': 0.10563289374113083,
#   'n_points': 54},
#  {'box': tensor([14.7972, -3.5312,  0.6069], device='cuda:0'),
#   'dim': tensor([1.9273, 1.1425, 1.5306], device='cuda:0'),
#   'distance': 0.07,
#   'cos_sim': tensor(0.9990, device='cuda:0'),
#   'volume': 4.71,
#   'label': 1,
#   'score': 0.26333364844322205,
#   'n_points': 37},
#  {'box': tensor([15.0055, -2.9736,  0.9569], device='cuda:0'),
#   'dim': tensor([4.5744, 2.1021, 1.5526], device='cuda:0'),
#   'distance': 0.0,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.39,
#   'label': 1,
#   'score': 0.7981426119804382,
#   'n_points': 59},
#  {'box': tensor([14.7750, -3.3597,  0.7849], device='cuda:0'),
#   'dim': tensor([3.3194, 1.2812, 1.5576], device='cuda:0'),
#   'distance': 0.15,
#   'cos_sim': tensor(0.9997, device='cuda:0'),
#   'volume': 17.62,
#   'label': 1,
#   'score': 0.2528766393661499,
#   'n_points': 55},
#  {'box': tensor([14.9362, -3.1316,  0.5621], device='cuda:0'),
#   'dim': tensor([3.9578, 1.7033, 1.4331], device='cuda:0'),
#   'distance': 0.03,
#   'cos_sim': tensor(0.9996, device='cuda:0'),
#   'volume': 1.58,
#   'label': 1,
#   'score': 0.16478204727172852,
#   'n_points': 51},
#  {'box': tensor([14.9834, -3.2273,  0.9195], device='cuda:0'),
#   'dim': tensor([4.8306, 2.1681, 1.6092], device='cuda:0'),
#   'distance': 0.03,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 1.53,
#   'label': 1,
#   'score': 0.14433100819587708,
#   'n_points': 43},
#  {'box': tensor([14.9505, -2.7631,  0.8866], device='cuda:0'),
#   'dim': tensor([4.2309, 2.0420, 1.7267], device='cuda:0'),
#   'distance': 0.09,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 9.33,
#   'label': 1,
#   'score': 0.4558747708797455,
#   'n_points': 68},
#  {'box': tensor([14.8968, -2.9543,  0.5836], device='cuda:0'),
#   'dim': tensor([2.3723, 1.0299, 1.1487], device='cuda:0'),
#   'distance': 0.1,
#   'cos_sim': tensor(0.9997, device='cuda:0'),
#   'volume': 5.27,
#   'label': 1,
#   'score': 0.19590596854686737,
#   'n_points': 54},
#  {'box': tensor([14.9602, -2.9109,  0.9548], device='cuda:0'),
#   'dim': tensor([4.4580, 2.0712, 1.5648], device='cuda:0'),
#   'distance': 0.06,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.87,
#   'label': 1,
#   'score': 0.7980029582977295,
#   'n_points': 40},
#  {'box': tensor([15.0462, -2.6680,  0.9434], device='cuda:0'),
#   'dim': tensor([4.3252, 2.0467, 1.7071], device='cuda:0'),
#   'distance': 0.01,
#   'cos_sim': tensor(0.9997, device='cuda:0'),
#   'volume': 9.13,
#   'label': 1,
#   'score': 0.4568829834461212,
#   'n_points': 64},
#  {'box': tensor([14.8626, -3.5583,  0.5311], device='cuda:0'),
#   'dim': tensor([4.0443, 2.1566, 1.5604], device='cuda:0'),
#   'distance': 0.01,
#   'cos_sim': tensor(0.9991, device='cuda:0'),
#   'volume': 5.53,
#   'label': 1,
#   'score': 0.21143454313278198,
#   'n_points': 54},
#  {'box': tensor([14.8485, -3.0084,  0.9982], device='cuda:0'),
#   'dim': tensor([4.3395, 2.0452, 1.6378], device='cuda:0'),
#   'distance': 0.15,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.79,
#   'label': 1,
#   'score': 0.6073989272117615,
#   'n_points': 36},
#  {'box': tensor([14.4297, -3.7309,  0.3857], device='cuda:0'),
#   'dim': tensor([0.8053, 0.7325, 1.5438], device='cuda:0'),
#   'distance': 0.39,
#   'cos_sim': tensor(0.9974, device='cuda:0'),
#   'volume': 3.08,
#   'label': 2,
#   'score': 0.1887759268283844,
#   'n_points': 8},
#  {'box': tensor([14.9163, -3.4932,  0.7453], device='cuda:0'),
#   'dim': tensor([3.7392, 1.9469, 1.7572], device='cuda:0'),
#   'distance': 0.02,
#   'cos_sim': tensor(0.9995, device='cuda:0'),
#   'volume': 11.45,
#   'label': 1,
#   'score': 0.1546912044286728,
#   'n_points': 77},
#  {'box': tensor([14.9665, -3.0174,  0.5883], device='cuda:0'),
#   'dim': tensor([3.6478, 1.5962, 1.3712], device='cuda:0'),
#   'distance': 0.02,
#   'cos_sim': tensor(0.9996, device='cuda:0'),
#   'volume': 0.09,
#   'label': 1,
#   'score': 0.2301018089056015,
#   'n_points': 77},
#  {'box': tensor([14.9270, -2.9683,  0.9812], device='cuda:0'),
#   'dim': tensor([4.4456, 2.0528, 1.5987], device='cuda:0'),
#   'distance': 0.09,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.73,
#   'label': 1,
#   'score': 0.5143082737922668,
#   'n_points': 26},
#  {'box': tensor([14.4711, -3.7436,  0.3016], device='cuda:0'),
#   'dim': tensor([0.9214, 0.7913, 1.6278], device='cuda:0'),
#   'distance': 0.35,
#   'cos_sim': tensor(0.9976, device='cuda:0'),
#   'volume': 2.8,
#   'label': 2,
#   'score': 0.22895881533622742,
#   'n_points': 9},
#  {'box': tensor([15.0641, -3.3188,  0.8734], device='cuda:0'),
#   'dim': tensor([3.8092, 1.9247, 1.7998], device='cuda:0'),
#   'distance': 0.13,
#   'cos_sim': tensor(0.9998, device='cuda:0'),
#   'volume': 11.05,
#   'label': 1,
#   'score': 0.17420044541358948,
#   'n_points': 73},
#  {'box': tensor([14.9807, -3.4718,  0.3879], device='cuda:0'),
#   'dim': tensor([2.0034, 1.1919, 1.4427], device='cuda:0'),
#   'distance': 0.08,
#   'cos_sim': tensor(0.9994, device='cuda:0'),
#   'volume': 4.63,
#   'label': 1,
#   'score': 0.37023115158081055,
#   'n_points': 70},
#  {'box': tensor([14.5824, -4.0879,  0.2086], device='cuda:0'),
#   'dim': tensor([1.7602, 0.8408, 1.7712], device='cuda:0'),
#   'distance': 0.15,
#   'cos_sim': tensor(0.9965, device='cuda:0'),
#   'volume': 1.37,
#   'label': 3,
#   'score': 0.13426020741462708,
#   'n_points': 8},
#  {'box': tensor([15.0668, -3.2652,  0.8807], device='cuda:0'),
#   'dim': tensor([4.2208, 1.9310, 1.8162], device='cuda:0'),
#   'distance': 0.12,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 9.44,
#   'label': 1,
#   'score': 0.1295148730278015,
#   'n_points': 96},
#  {'box': tensor([14.8969, -3.0206,  0.5361], device='cuda:0'),
#   'dim': tensor([3.7941, 1.7665, 1.4724], device='cuda:0'),
#   'distance': 0.09,
#   'cos_sim': tensor(0.9997, device='cuda:0'),
#   'volume': 1.79,
#   'label': 1,
#   'score': 0.14468035101890564,
#   'n_points': 80},
#  {'box': tensor([15.0691, -3.3987,  0.8025], device='cuda:0'),
#   'dim': tensor([3.7553, 2.0209, 1.8314], device='cuda:0'),
#   'distance': 0.15,
#   'cos_sim': tensor(0.9997, device='cuda:0'),
#   'volume': 10.35,
#   'label': 1,
#   'score': 0.22356410324573517,
#   'n_points': 99},
#  {'box': tensor([15.1089, -3.9458,  0.6065], device='cuda:0'),
#   'dim': tensor([0.9602, 0.8885, 1.6782], device='cuda:0'),
#   'distance': 0.33,
#   'cos_sim': tensor(0.9979, device='cuda:0'),
#   'volume': 6.65,
#   'label': 2,
#   'score': 0.40776199102401733,
#   'n_points': 89},
#  {'box': tensor([14.9416, -3.0413,  0.4219], device='cuda:0'),
#   'dim': tensor([3.1502, 2.0832, 1.4377], device='cuda:0'),
#   'distance': 0.04,
#   'cos_sim': tensor(0.9998, device='cuda:0'),
#   'volume': 1.36,
#   'label': 1,
#   'score': 0.16207624971866608,
#   'n_points': 98},
#  {'box': tensor([14.4854, -2.4720,  1.2165], device='cuda:0'),
#   'dim': tensor([1.0181, 0.9675, 1.8813], device='cuda:0'),
#   'distance': 0.6,
#   'cos_sim': tensor(0.9996, device='cuda:0'),
#   'volume': 19.4,
#   'label': 2,
#   'score': 0.5962525606155396,
#   'n_points': 39},
#  {'box': tensor([14.2333, -3.7934,  0.4538], device='cuda:0'),
#   'dim': tensor([0.8956, 0.7979, 1.6620], device='cuda:0'),
#   'distance': 0.57,
#   'cos_sim': tensor(0.9964, device='cuda:0'),
#   'volume': 2.8,
#   'label': 2,
#   'score': 0.10619796812534332,
#   'n_points': 10},
#  {'box': tensor([14.6765, -2.5793,  0.9781], device='cuda:0'),
#   'dim': tensor([1.2839, 0.9317, 1.8625], device='cuda:0'),
#   'distance': 0.41,
#   'cos_sim': tensor(0.9996, device='cuda:0'),
#   'volume': 19.02,
#   'label': 2,
#   'score': 0.10801374167203903,
#   'n_points': 54},
#  {'box': tensor([14.6982, -3.6125,  1.6736], device='cuda:0'),
#   'dim': tensor([4.6862, 2.5415, 2.8823], device='cuda:0'),
#   'distance': 0.12,
#   'cos_sim': tensor(0.9987, device='cuda:0'),
#   'volume': 13.08,
#   'label': 1,
#   'score': 0.1056293249130249,
#   'n_points': 53},
#  {'box': tensor([14.9468, -3.0631,  1.0118], device='cuda:0'),
#   'dim': tensor([4.5112, 2.0689, 1.6928], device='cuda:0'),
#   'distance': 0.03,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.42,
#   'label': 1,
#   'score': 0.8535945415496826,
#   'n_points': 58},
#  {'box': tensor([14.6263, -2.3462,  1.6216], device='cuda:0'),
#   'dim': tensor([1.1069, 0.9741, 1.8860], device='cuda:0'),
#   'distance': 0.45,
#   'cos_sim': tensor(0.9990, device='cuda:0'),
#   'volume': 19.22,
#   'label': 2,
#   'score': 0.12027552723884583,
#   'n_points': 61},
#  {'box': tensor([14.8851, -2.9558,  0.9148], device='cuda:0'),
#   'dim': tensor([4.3888, 1.9901, 1.5792], device='cuda:0'),
#   'distance': 0.12,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 2.42,
#   'label': 1,
#   'score': 0.8135638236999512,
#   'n_points': 54},
#  {'box': tensor([14.6440, -2.6138,  1.6941], device='cuda:0'),
#   'dim': tensor([1.2054, 1.0573, 1.9499], device='cuda:0'),
#   'distance': 0.38,
#   'cos_sim': tensor(0.9994, device='cuda:0'),
#   'volume': 18.76,
#   'label': 2,
#   'score': 0.11956802010536194,
#   'n_points': 64},
#  {'box': tensor([15.0353, -2.7866,  1.1310], device='cuda:0'),
#   'dim': tensor([4.6796, 2.1309, 1.6816], device='cuda:0'),
#   'distance': 0.04,
#   'cos_sim': tensor(0.9996, device='cuda:0'),
#   'volume': 1.19,
#   'label': 1,
#   'score': 0.6170120239257812,
#   'n_points': 33},
#  {'box': tensor([14.8829, -2.9131,  0.8965], device='cuda:0'),
#   'dim': tensor([4.4348, 1.9986, 1.5111], device='cuda:0'),
#   'distance': 0.13,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 2.82,
#   'label': 1,
#   'score': 0.8538787364959717,
#   'n_points': 74},
#  {'box': tensor([14.7555, -2.2682,  1.5574], device='cuda:0'),
#   'dim': tensor([1.1716, 1.0436, 1.9679], device='cuda:0'),
#   'distance': 0.34,
#   'cos_sim': tensor(0.9988, device='cuda:0'),
#   'volume': 18.84,
#   'label': 2,
#   'score': 0.15232302248477936,
#   'n_points': 71},
#  {'box': tensor([14.9002, -3.0083,  1.1519], device='cuda:0'),
#   'dim': tensor([4.4755, 2.0655, 1.7102], device='cuda:0'),
#   'distance': 0.12,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 0.23,
#   'label': 1,
#   'score': 0.7244176268577576,
#   'n_points': 47},
#  {'box': tensor([14.8976, -2.9718,  0.9184], device='cuda:0'),
#   'dim': tensor([4.3803, 2.0172, 1.5458], device='cuda:0'),
#   'distance': 0.11,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 2.56,
#   'label': 1,
#   'score': 0.8463174700737,
#   'n_points': 60},
#  {'box': tensor([14.6938, -2.3518,  1.3633], device='cuda:0'),
#   'dim': tensor([1.1120, 1.0149, 1.8930], device='cuda:0'),
#   'distance': 0.41,
#   'cos_sim': tensor(0.9992, device='cuda:0'),
#   'volume': 19.11,
#   'label': 2,
#   'score': 0.2538905441761017,
#   'n_points': 75},
#  {'box': tensor([14.9812, -2.8874,  1.0656], device='cuda:0'),
#   'dim': tensor([4.6702, 2.1211, 1.5843], device='cuda:0'),
#   'distance': 0.06,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 0.12,
#   'label': 1,
#   'score': 0.8314650058746338,
#   'n_points': 50},
#  {'box': tensor([14.9559, -3.0024,  0.9875], device='cuda:0'),
#   'dim': tensor([4.4356, 2.0498, 1.5917], device='cuda:0'),
#   'distance': 0.04,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.75,
#   'label': 1,
#   'score': 0.8461033701896667,
#   'n_points': 63},
#  {'box': tensor([14.7751, -2.3277,  1.7450], device='cuda:0'),
#   'dim': tensor([1.2223, 1.0621, 1.9488], device='cuda:0'),
#   'distance': 0.29,
#   'cos_sim': tensor(0.9986, device='cuda:0'),
#   'volume': 18.72,
#   'label': 2,
#   'score': 0.12443344295024872,
#   'n_points': 82},
#  {'box': tensor([14.9664, -2.9332,  1.1256], device='cuda:0'),
#   'dim': tensor([4.5823, 2.0758, 1.5853], device='cuda:0'),
#   'distance': 0.06,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 0.5,
#   'label': 1,
#   'score': 0.8407332897186279,
#   'n_points': 61},
#  {'box': tensor([14.8082, -3.0426,  0.8386], device='cuda:0'),
#   'dim': tensor([4.2597, 1.9990, 1.4549], device='cuda:0'),
#   'distance': 0.18,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 3.83,
#   'label': 1,
#   'score': 0.8283488154411316,
#   'n_points': 41},
#  {'box': tensor([14.9135, -2.9997,  1.1467], device='cuda:0'),
#   'dim': tensor([4.5345, 2.0600, 1.5550], device='cuda:0'),
#   'distance': 0.1,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 1.05,
#   'label': 1,
#   'score': 0.857804536819458,
#   'n_points': 63},
#  {'box': tensor([15.5987, -2.8203,  0.3720], device='cuda:0'),
#   'dim': tensor([0.9424, 0.8572, 1.6748], device='cuda:0'),
#   'distance': 0.56,
#   'cos_sim': tensor(0.9991, device='cuda:0'),
#   'volume': 2.64,
#   'label': 2,
#   'score': 0.17867733538150787,
#   'n_points': 7},
#  {'box': tensor([14.8576, -3.0353,  0.8137], device='cuda:0'),
#   'dim': tensor([4.1596, 1.9450, 1.4007], device='cuda:0'),
#   'distance': 0.13,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 4.88,
#   'label': 1,
#   'score': 0.6757099032402039,
#   'n_points': 32},
#  {'box': tensor([14.9102, -2.8479,  0.9226], device='cuda:0'),
#   'dim': tensor([4.4059, 1.9946, 1.5334], device='cuda:0'),
#   'distance': 0.11,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 3.33,
#   'label': 1,
#   'score': 0.8976851105690002,
#   'n_points': 96},
#  {'box': tensor([14.9181, -3.0173,  1.1509], device='cuda:0'),
#   'dim': tensor([4.5620, 2.0791, 1.5793], device='cuda:0'),
#   'distance': 0.09,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.6,
#   'label': 1,
#   'score': 0.8895132541656494,
#   'n_points': 76},
#  {'box': tensor([14.8783, -3.0782,  0.7896], device='cuda:0'),
#   'dim': tensor([4.2058, 1.9532, 1.4081], device='cuda:0'),
#   'distance': 0.1,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 4.65,
#   'label': 1,
#   'score': 0.7198908925056458,
#   'n_points': 27},
#  {'box': tensor([14.9034, -2.9652,  0.7870], device='cuda:0'),
#   'dim': tensor([4.7142, 2.1250, 1.5424], device='cuda:0'),
#   'distance': 0.1,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.36,
#   'label': 1,
#   'score': 0.49781960248947144,
#   'n_points': 33},
#  {'box': tensor([14.9643, -3.0798,  0.8269], device='cuda:0'),
#   'dim': tensor([4.2273, 1.9526, 1.4088], device='cuda:0'),
#   'distance': 0.01,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 4.59,
#   'label': 1,
#   'score': 0.5794067978858948,
#   'n_points': 29},
#  {'box': tensor([14.6861, -1.5865,  0.6483], device='cuda:0'),
#   'dim': tensor([2.7141, 1.1653, 1.2041], device='cuda:0'),
#   'distance': 0.52,
#   'cos_sim': tensor(0.9958, device='cuda:0'),
#   'volume': 19.71,
#   'label': 1,
#   'score': 0.12493741512298584,
#   'n_points': 30},
#  {'box': tensor([15.0430, -2.9921,  0.8313], device='cuda:0'),
#   'dim': tensor([4.3533, 2.0102, 1.4942], device='cuda:0'),
#   'distance': 0.05,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 3.14,
#   'label': 1,
#   'score': 0.40815073251724243,
#   'n_points': 26},
#  {'box': tensor([14.8316, -2.8670,  0.2789], device='cuda:0'),
#   'dim': tensor([2.9350, 2.3038, 1.3946], device='cuda:0'),
#   'distance': 0.19,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 14.09,
#   'label': 1,
#   'score': 0.2862459719181061,
#   'n_points': 72},
#  {'box': tensor([15.0390, -2.9714,  0.8169], device='cuda:0'),
#   'dim': tensor([4.2753, 1.9328, 1.4351], device='cuda:0'),
#   'distance': 0.05,
#   'cos_sim': tensor(0.9998, device='cuda:0'),
#   'volume': 4.36,
#   'label': 1,
#   'score': 0.29362162947654724,
#   'n_points': 18},
#  {'box': tensor([14.8266, -2.6906,  0.8833], device='cuda:0'),
#   'dim': tensor([4.9349, 2.1165, 1.6588], device='cuda:0'),
#   'distance': 0.21,
#   'cos_sim': tensor(0.9996, device='cuda:0'),
#   'volume': 13.32,
#   'label': 1,
#   'score': 0.4648038148880005,
#   'n_points': 40},
#  {'box': tensor([14.8709, -3.5689, -0.0476], device='cuda:0'),
#   'dim': tensor([4.1029, 1.9785, 1.4981], device='cuda:0'),
#   'distance': 0.0,
#   'cos_sim': tensor(0.9992, device='cuda:0'),
#   'volume': 11.36,
#   'label': 1,
#   'score': 0.10844381898641586,
#   'n_points': 61},
#  {'box': tensor([14.2886, -3.5628,  0.2456], device='cuda:0'),
#   'dim': tensor([0.8835, 0.7996, 1.6597], device='cuda:0'),
#   'distance': 0.57,
#   'cos_sim': tensor(0.9983, device='cuda:0'),
#   'volume': 2.82,
#   'label': 2,
#   'score': 0.14015114307403564,
#   'n_points': 35},
#  {'box': tensor([14.9194, -2.7013,  0.9469], device='cuda:0'),
#   'dim': tensor([4.0633, 1.7502, 1.6156], device='cuda:0'),
#   'distance': 0.12,
#   'cos_sim': tensor(0.9997, device='cuda:0'),
#   'volume': 5.32,
#   'label': 1,
#   'score': 0.10189837962388992,
#   'n_points': 13},
#  {'box': tensor([15.0072, -2.7009,  0.0700], device='cuda:0'),
#   'dim': tensor([4.2832, 1.9792, 1.5613], device='cuda:0'),
#   'distance': 0.05,
#   'cos_sim': tensor(0.9996, device='cuda:0'),
#   'volume': 10.28,
#   'label': 1,
#   'score': 0.2002408504486084,
#   'n_points': 45},
#  {'box': tensor([14.8886, -3.2805,  1.0436], device='cuda:0'),
#   'dim': tensor([3.3183, 1.7480, 1.7382], device='cuda:0'),
#   'distance': 0.07,
#   'cos_sim': tensor(0.9997, device='cuda:0'),
#   'volume': 4.01,
#   'label': 1,
#   'score': 0.120406374335289,
#   'n_points': 11},
#  {'box': tensor([14.9138, -2.6835,  1.0610], device='cuda:0'),
#   'dim': tensor([4.3874, 2.0435, 1.7146], device='cuda:0'),
#   'distance': 0.15,
#   'cos_sim': tensor(0.9998, device='cuda:0'),
#   'volume': 1.44,
#   'label': 1,
#   'score': 0.5500487685203552,
#   'n_points': 27},
#  {'box': tensor([14.8442, -3.6915,  0.0261], device='cuda:0'),
#   'dim': tensor([4.0438, 1.8296, 1.6175], device='cuda:0'),
#   'distance': 0.01,
#   'cos_sim': tensor(0.9985, device='cuda:0'),
#   'volume': 11.55,
#   'label': 1,
#   'score': 0.13400186598300934,
#   'n_points': 55},
#  {'box': tensor([14.4105, -3.8518, -0.1307], device='cuda:0'),
#   'dim': tensor([0.7735, 0.7324, 1.1158], device='cuda:0'),
#   'distance': 0.39,
#   'cos_sim': tensor(0.9976, device='cuda:0'),
#   'volume': 3.36,
#   'label': 2,
#   'score': 0.13979992270469666,
#   'n_points': 39},
#  {'box': tensor([15.0183, -2.6142,  1.2910], device='cuda:0'),
#   'dim': tensor([4.5873, 2.0920, 1.7203], device='cuda:0'),
#   'distance': 0.06,
#   'cos_sim': tensor(0.9997, device='cuda:0'),
#   'volume': 0.3,
#   'label': 1,
#   'score': 0.7660049200057983,
#   'n_points': 36},
#  {'box': tensor([14.9241, -3.3834,  0.8694], device='cuda:0'),
#   'dim': tensor([2.8904, 1.5784, 1.5286], device='cuda:0'),
#   'distance': 0.01,
#   'cos_sim': tensor(0.9997, device='cuda:0'),
#   'volume': 7.12,
#   'label': 1,
#   'score': 0.16573530435562134,
#   'n_points': 16},
#  {'box': tensor([15.0020, -2.9444,  1.0889], device='cuda:0'),
#   'dim': tensor([4.5725, 2.1061, 1.7338], device='cuda:0'),
#   'distance': 0.01,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.11,
#   'label': 1,
#   'score': 0.7786062359809875,
#   'n_points': 43},
#  {'box': tensor([14.4362, -3.8834,  0.2871], device='cuda:0'),
#   'dim': tensor([0.9674, 0.8489, 1.6402], device='cuda:0'),
#   'distance': 0.35,
#   'cos_sim': tensor(0.9974, device='cuda:0'),
#   'volume': 2.64,
#   'label': 2,
#   'score': 0.12178467214107513,
#   'n_points': 35},
#  {'box': tensor([14.9834, -2.3792,  0.9795], device='cuda:0'),
#   'dim': tensor([4.9085, 2.2517, 1.7174], device='cuda:0'),
#   'distance': 0.13,
#   'cos_sim': tensor(0.9992, device='cuda:0'),
#   'volume': 4.89,
#   'label': 1,
#   'score': 0.13060669600963593,
#   'n_points': 22},
#  {'box': tensor([14.5418, -2.9132,  0.9686], device='cuda:0'),
#   'dim': tensor([4.6598, 2.1784, 1.7197], device='cuda:0'),
#   'distance': 0.45,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 5.41,
#   'label': 1,
#   'score': 0.8012039065361023,
#   'n_points': 74},
#  {'box': tensor([14.2022, -3.7261,  0.3521], device='cuda:0'),
#   'dim': tensor([0.8553, 0.7606, 1.6028], device='cuda:0'),
#   'distance': 0.61,
#   'cos_sim': tensor(0.9978, device='cuda:0'),
#   'volume': 2.95,
#   'label': 2,
#   'score': 0.17164704203605652,
#   'n_points': 34},
#  {'box': tensor([14.9246, -2.8004,  0.9628], device='cuda:0'),
#   'dim': tensor([4.5299, 2.1141, 1.6477], device='cuda:0'),
#   'distance': 0.12,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 1.69,
#   'label': 1,
#   'score': 0.7294348478317261,
#   'n_points': 22},
#  {'box': tensor([14.6280, -2.8707,  0.9430], device='cuda:0'),
#   'dim': tensor([4.7746, 2.2090, 1.6655], device='cuda:0'),
#   'distance': 0.38,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 5.3,
#   'label': 1,
#   'score': 0.7900838851928711,
#   'n_points': 64},
#  {'box': tensor([14.8620, -2.0749,  0.7330], device='cuda:0'),
#   'dim': tensor([4.3980, 1.8986, 1.3919], device='cuda:0'),
#   'distance': 0.29,
#   'cos_sim': tensor(0.9983, device='cuda:0'),
#   'volume': 15.92,
#   'label': 1,
#   'score': 0.10680948942899704,
#   'n_points': 18},
#  {'box': tensor([14.4355, -3.6813,  0.2210], device='cuda:0'),
#   'dim': tensor([1.0536, 0.8632, 1.6638], device='cuda:0'),
#   'distance': 0.4,
#   'cos_sim': tensor(0.9985, device='cuda:0'),
#   'volume': 2.48,
#   'label': 2,
#   'score': 0.1969843953847885,
#   'n_points': 29},
#  {'box': tensor([14.7196, -3.0546,  1.1831], device='cuda:0'),
#   'dim': tensor([4.7934, 2.2058, 1.8471], device='cuda:0'),
#   'distance': 0.27,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 4.75,
#   'label': 1,
#   'score': 0.4628675580024719,
#   'n_points': 22},
#  {'box': tensor([14.7722, -3.0024,  0.9921], device='cuda:0'),
#   'dim': tensor([4.2340, 2.0073, 1.5643], device='cuda:0'),
#   'distance': 0.22,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.8,
#   'label': 1,
#   'score': 0.805474042892456,
#   'n_points': 31},
# ...
#   'dim': tensor([5.5008, 2.3066, 1.8460], device='cuda:0'),
#   'distance': 0.07,
#   'cos_sim': tensor(0.9984, device='cuda:0'),
#   'volume': 12.16,
#   'label': 1,
#   'score': 0.23266617953777313,
#   'n_points': 77},
#  {'box': tensor([15.9450, -2.4571,  0.3171], device='cuda:0'),
#   'dim': tensor([0.7068, 0.6956, 1.4114], device='cuda:0'),
#   'distance': 0.84,
#   'cos_sim': tensor(0.9989, device='cuda:0'),
#   'volume': 3.29,
#   'label': 2,
#   'score': 0.5043706893920898,
#   'n_points': 20},
#  {'box': tensor([14.7281, -3.0427,  1.1811], device='cuda:0'),
#   'dim': tensor([4.8851, 2.2502, 1.8664], device='cuda:0'),
#   'distance': 0.25,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 3.77,
#   'label': 1,
#   'score': 0.5195270776748657,
#   'n_points': 28},
#  {'box': tensor([14.9431, -2.6017,  0.7662], device='cuda:0'),
#   'dim': tensor([4.4665, 2.0284, 1.4919], device='cuda:0'),
#   'distance': 0.11,
#   'cos_sim': tensor(0.9991, device='cuda:0'),
#   'volume': 4.94,
#   'label': 1,
#   'score': 0.18477654457092285,
#   'n_points': 29},
#  {'box': tensor([14.8485, -2.8891,  0.8857], device='cuda:0'),
#   'dim': tensor([4.4578, 2.0738, 1.5114], device='cuda:0'),
#   'distance': 0.17,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.12,
#   'label': 1,
#   'score': 0.8611809015274048,
#   'n_points': 41},
#  {'box': tensor([14.6525, -2.8985,  1.6706], device='cuda:0'),
#   'dim': tensor([8.9681, 2.9858, 2.8524], device='cuda:0'),
#   'distance': 0.36,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 8.32,
#   'label': 1,
#   'score': 0.17235827445983887,
#   'n_points': 72},
#  {'box': tensor([15.6709, -1.2452,  0.9260], device='cuda:0'),
#   'dim': tensor([4.5944, 2.0299, 1.5606], device='cuda:0'),
#   'distance': 0.42,
#   'cos_sim': tensor(0.9930, device='cuda:0'),
#   'volume': 12.99,
#   'label': 1,
#   'score': 0.11157557368278503,
#   'n_points': 19},
#  {'box': tensor([15.8827, -2.3357,  0.3372], device='cuda:0'),
#   'dim': tensor([0.7146, 0.6966, 1.1869], device='cuda:0'),
#   'distance': 0.76,
#   'cos_sim': tensor(0.9986, device='cuda:0'),
#   'volume': 3.4,
#   'label': 2,
#   'score': 0.6273370385169983,
#   'n_points': 27},
#  {'box': tensor([14.6962, -3.0230,  1.2268], device='cuda:0'),
#   'dim': tensor([5.0333, 2.2800, 1.9509], device='cuda:0'),
#   'distance': 0.3,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.9,
#   'label': 1,
#   'score': 0.49550309777259827,
#   'n_points': 34},
#  {'box': tensor([14.7987, -2.9818,  0.9884], device='cuda:0'),
#   'dim': tensor([4.3332, 2.0279, 1.5671], device='cuda:0'),
#   'distance': 0.2,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.32,
#   'label': 1,
#   'score': 0.8549712896347046,
#   'n_points': 61},
#  {'box': tensor([15.5801, -2.8486,  1.8169], device='cuda:0'),
#   'dim': tensor([10.9349,  3.0460,  2.9913], device='cuda:0'),
#   'distance': 0.53,
#   'cos_sim': tensor(0.9998, device='cuda:0'),
#   'volume': 31.57,
#   'label': 1,
#   'score': 0.2050892859697342,
#   'n_points': 82},
#  {'box': tensor([15.0499, -1.2073,  0.7269], device='cuda:0'),
#   'dim': tensor([3.4119, 1.6479, 1.3064], device='cuda:0'),
#   'distance': 0.21,
#   'cos_sim': tensor(0.9930, device='cuda:0'),
#   'volume': 20.19,
#   'label': 1,
#   'score': 0.13228842616081238,
#   'n_points': 20},
#  {'box': tensor([15.8813, -2.3472,  0.3563], device='cuda:0'),
#   'dim': tensor([0.7789, 0.7550, 1.4064], device='cuda:0'),
#   'distance': 0.76,
#   'cos_sim': tensor(0.9986, device='cuda:0'),
#   'volume': 3.16,
#   'label': 2,
#   'score': 0.540925920009613,
#   'n_points': 43},
#  {'box': tensor([14.8580, -3.0723,  1.2703], device='cuda:0'),
#   'dim': tensor([5.1795, 2.3573, 1.9425], device='cuda:0'),
#   'distance': 0.13,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.57,
#   'label': 1,
#   'score': 0.6342719197273254,
#   'n_points': 36},
#  {'box': tensor([14.8631, -2.6722,  0.7182], device='cuda:0'),
#   'dim': tensor([4.3887, 1.8908, 1.3726], device='cuda:0'),
#   'distance': 0.18,
#   'cos_sim': tensor(0.9988, device='cuda:0'),
#   'volume': 7.07,
#   'label': 1,
#   'score': 0.1258803904056549,
#   'n_points': 32},
#  {'box': tensor([15.0471, -2.9779,  0.9161], device='cuda:0'),
#   'dim': tensor([4.7162, 2.1251, 1.5625], device='cuda:0'),
#   'distance': 0.04,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 1.57,
#   'label': 1,
#   'score': 0.7729629278182983,
#   'n_points': 73},
#  {'box': tensor([15.4417, -2.9346,  1.8264], device='cuda:0'),
#   'dim': tensor([10.3257,  3.0565,  2.9154], device='cuda:0'),
#   'distance': 0.41,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 23.95,
#   'label': 1,
#   'score': 0.20489047467708588,
#   'n_points': 77},
#  {'box': tensor([15.7362, -1.1794,  0.8610], device='cuda:0'),
#   'dim': tensor([4.6654, 2.0233, 1.5194], device='cuda:0'),
#   'distance': 0.48,
#   'cos_sim': tensor(0.9925, device='cuda:0'),
#   'volume': 13.2,
#   'label': 1,
#   'score': 0.15349845588207245,
#   'n_points': 21},
#  {'box': tensor([15.9042, -2.3611,  0.3365], device='cuda:0'),
#   'dim': tensor([0.7629, 0.7461, 1.3395], device='cuda:0'),
#   'distance': 0.78,
#   'cos_sim': tensor(0.9986, device='cuda:0'),
#   'volume': 3.23,
#   'label': 2,
#   'score': 0.5095733404159546,
#   'n_points': 56},
#  {'box': tensor([14.9073, -3.1047,  1.1404], device='cuda:0'),
#   'dim': tensor([5.1544, 2.3289, 1.9412], device='cuda:0'),
#   'distance': 0.07,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.98,
#   'label': 1,
#   'score': 0.7327238321304321,
#   'n_points': 52},
#  {'box': tensor([14.8632, -3.2206,  0.6699], device='cuda:0'),
#   'dim': tensor([4.7453, 2.1495, 1.4410], device='cuda:0'),
#   'distance': 0.08,
#   'cos_sim': tensor(0.9995, device='cuda:0'),
#   'volume': 3.76,
#   'label': 1,
#   'score': 0.14473609626293182,
#   'n_points': 31},
#  {'box': tensor([15.5075, -2.7714,  1.7440], device='cuda:0'),
#   'dim': tensor([9.3018, 3.0635, 2.9550], device='cuda:0'),
#   'distance': 0.46,
#   'cos_sim': tensor(0.9998, device='cuda:0'),
#   'volume': 16.15,
#   'label': 1,
#   'score': 0.3999447226524353,
#   'n_points': 81},
#  {'box': tensor([15.8174, -2.3574,  0.2993], device='cuda:0'),
#   'dim': tensor([0.8998, 0.8568, 1.4081], device='cuda:0'),
#   'distance': 0.7,
#   'cos_sim': tensor(0.9987, device='cuda:0'),
#   'volume': 2.9,
#   'label': 2,
#   'score': 0.3830436170101166,
#   'n_points': 80},
#  {'box': tensor([14.8730, -3.0652,  1.1131], device='cuda:0'),
#   'dim': tensor([5.1464, 2.2575, 1.8303], device='cuda:0'),
#   'distance': 0.11,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 3.02,
#   'label': 1,
#   'score': 0.8234171271324158,
#   'n_points': 60},
#  {'box': tensor([14.8645, -3.2378,  0.7857], device='cuda:0'),
#   'dim': tensor([4.7034, 2.1218, 1.4835], device='cuda:0'),
#   'distance': 0.07,
#   'cos_sim': tensor(0.9995, device='cuda:0'),
#   'volume': 3.65,
#   'label': 1,
#   'score': 0.14057375490665436,
#   'n_points': 41},
#  {'box': tensor([14.5575, -4.1524,  1.2463], device='cuda:0'),
#   'dim': tensor([1.0639, 0.8494, 1.6398], device='cuda:0'),
#   'distance': 0.19,
#   'cos_sim': tensor(0.9966, device='cuda:0'),
#   'volume': 66.58,
#   'label': 2,
#   'score': 0.11428745836019516,
#   'n_points': 78},
#  {'box': tensor([14.8637, -2.6244,  0.9483], device='cuda:0'),
#   'dim': tensor([4.5692, 2.0472, 1.6011], device='cuda:0'),
#   'distance': 0.2,
#   'cos_sim': tensor(0.9997, device='cuda:0'),
#   'volume': 12.56,
#   'label': 1,
#   'score': 0.44094571471214294,
#   'n_points': 23},
#  {'box': tensor([14.8697, -3.1141,  1.0508], device='cuda:0'),
#   'dim': tensor([5.0684, 2.2053, 1.7600], device='cuda:0'),
#   'distance': 0.1,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 4.61,
#   'label': 1,
#   'score': 0.7887618541717529,
#   'n_points': 85},
#  {'box': tensor([14.8157, -2.9818,  0.7949], device='cuda:0'),
#   'dim': tensor([4.4153, 2.0285, 1.4124], device='cuda:0'),
#   'distance': 0.17,
#   'cos_sim': tensor(0.9995, device='cuda:0'),
#   'volume': 5.81,
#   'label': 1,
#   'score': 0.7669338583946228,
#   'n_points': 40},
#  {'box': tensor([15.5429, -2.8631,  1.7346], device='cuda:0'),
#   'dim': tensor([9.3674, 3.0682, 2.9845], device='cuda:0'),
#   'distance': 0.52,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 17.72,
#   'label': 1,
#   'score': 0.40765368938446045,
#   'n_points': 88},
#  {'box': tensor([14.8304, -3.2322,  0.6885], device='cuda:0'),
#   'dim': tensor([4.8274, 2.1050, 1.4301], device='cuda:0'),
#   'distance': 0.1,
#   'cos_sim': tensor(0.9994, device='cuda:0'),
#   'volume': 3.93,
#   'label': 1,
#   'score': 0.13403435051441193,
#   'n_points': 31},
#  {'box': tensor([15.4757, -3.0067,  1.9229], device='cuda:0'),
#   'dim': tensor([10.0226,  3.1454,  2.9533], device='cuda:0'),
#   'distance': 0.49,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 25.04,
#   'label': 1,
#   'score': 0.29954710602760315,
#   'n_points': 94},
#  {'box': tensor([14.7659, -3.2547,  0.5577], device='cuda:0'),
#   'dim': tensor([3.8418, 1.8545, 1.3893], device='cuda:0'),
#   'distance': 0.17,
#   'cos_sim': tensor(0.9995, device='cuda:0'),
#   'volume': 8.56,
#   'label': 1,
#   'score': 0.1238374188542366,
#   'n_points': 35},
#  {'box': tensor([14.6344, -3.3400,  1.5728], device='cuda:0'),
#   'dim': tensor([6.0467, 2.3943, 2.2536], device='cuda:0'),
#   'distance': 0.3,
#   'cos_sim': tensor(0.9996, device='cuda:0'),
#   'volume': 35.43,
#   'label': 1,
#   'score': 0.22310742735862732,
#   'n_points': 92},
#  {'box': tensor([14.7729, -2.7480,  0.6990], device='cuda:0'),
#   'dim': tensor([4.4369, 1.9066, 1.3531], device='cuda:0'),
#   'distance': 0.26,
#   'cos_sim': tensor(0.9993, device='cuda:0'),
#   'volume': 7.01,
#   'label': 1,
#   'score': 0.2237199991941452,
#   'n_points': 33},
#  {'box': tensor([14.8636, -2.7775,  0.6747], device='cuda:0'),
#   'dim': tensor([4.4591, 2.0653, 1.4366], device='cuda:0'),
#   'distance': 0.16,
#   'cos_sim': tensor(0.9994, device='cuda:0'),
#   'volume': 5.23,
#   'label': 1,
#   'score': 0.28429627418518066,
#   'n_points': 35},
#  {'box': tensor([14.7701, -2.8927,  1.8468], device='cuda:0'),
#   'dim': tensor([7.5069, 2.9723, 2.9003], device='cuda:0'),
#   'distance': 0.23,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 3.34,
#   'label': 1,
#   'score': 0.5411189198493958,
#   'n_points': 91},
#  {'box': tensor([14.8379, -2.7189,  0.7124], device='cuda:0'),
#   'dim': tensor([4.3176, 1.8123, 1.3108], device='cuda:0'),
#   'distance': 0.2,
#   'cos_sim': tensor(0.9993, device='cuda:0'),
#   'volume': 8.2,
#   'label': 1,
#   'score': 0.10000909119844437,
#   'n_points': 33},
#  {'box': tensor([14.7920, -3.2704,  0.6507], device='cuda:0'),
#   'dim': tensor([4.6601, 2.0208, 1.3833], device='cuda:0'),
#   'distance': 0.14,
#   'cos_sim': tensor(0.9993, device='cuda:0'),
#   'volume': 5.43,
#   'label': 1,
#   'score': 0.12622283399105072,
#   'n_points': 31},
#  {'box': tensor([14.7267, -3.8823,  1.6821], device='cuda:0'),
#   'dim': tensor([1.0706, 0.8882, 1.9626], device='cuda:0'),
#   'distance': 0.05,
#   'cos_sim': tensor(0.9982, device='cuda:0'),
#   'volume': 25.67,
#   'label': 2,
#   'score': 0.10041399300098419,
#   'n_points': 7},
#  {'box': tensor([14.7971, -3.3196,  0.6936], device='cuda:0'),
#   'dim': tensor([4.6624, 1.9982, 1.4188], device='cuda:0'),
#   'distance': 0.12,
#   'cos_sim': tensor(0.9992, device='cuda:0'),
#   'volume': 5.24,
#   'label': 1,
#   'score': 0.12896977365016937,
#   'n_points': 31},
#  {'box': tensor([14.8017, -4.3965,  1.7267], device='cuda:0'),
#   'dim': tensor([1.1591, 0.9679, 1.8971], device='cuda:0'),
#   'distance': 0.16,
#   'cos_sim': tensor(0.9959, device='cuda:0'),
#   'volume': 25.41,
#   'label': 2,
#   'score': 0.16119588911533356,
#   'n_points': 10},
#  {'box': tensor([14.8325, -3.2420,  0.6525], device='cuda:0'),
#   'dim': tensor([4.5687, 2.0842, 1.4352], device='cuda:0'),
#   'distance': 0.1,
#   'cos_sim': tensor(0.9995, device='cuda:0'),
#   'volume': 4.79,
#   'label': 1,
#   'score': 0.19175101816654205,
#   'n_points': 33},
#  {'box': tensor([14.7933, -2.8780,  0.6839], device='cuda:0'),
#   'dim': tensor([4.3119, 1.8794, 1.2374], device='cuda:0'),
#   'distance': 0.21,
#   'cos_sim': tensor(0.9996, device='cuda:0'),
#   'volume': 8.43,
#   'label': 1,
#   'score': 0.25507375597953796,
#   'n_points': 29},
#  {'box': tensor([14.8923, -3.3223,  1.5286], device='cuda:0'),
#   'dim': tensor([2.9191, 1.7101, 2.0369], device='cuda:0'),
#   'distance': 0.02,
#   'cos_sim': tensor(0.9997, device='cuda:0'),
#   'volume': 30.4,
#   'label': 1,
#   'score': 0.23849046230316162,
#   'n_points': 41},
#  {'box': tensor([14.8204, -2.8213,  0.7275], device='cuda:0'),
#   'dim': tensor([4.4117, 1.9787, 1.3750], device='cuda:0'),
#   'distance': 0.19,
#   'cos_sim': tensor(0.9994, device='cuda:0'),
#   'volume': 6.45,
#   'label': 1,
#   'score': 0.1735198050737381,
#   'n_points': 24},
#  {'box': tensor([14.9642, -2.9441,  1.4730], device='cuda:0'),
#   'dim': tensor([5.5404, 2.4875, 2.3067], device='cuda:0'),
#   'distance': 0.04,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 8.78,
#   'label': 1,
#   'score': 0.7736188769340515,
#   'n_points': 48},
#  {'box': tensor([14.9460, -2.8346,  1.6642], device='cuda:0'),
#   'dim': tensor([5.5065, 2.4160, 2.1875], device='cuda:0'),
#   'distance': 0.07,
#   'cos_sim': tensor(0.9999, device='cuda:0'),
#   'volume': 11.46,
#   'label': 1,
#   'score': 0.8864855766296387,
#   'n_points': 55},
#  {'box': tensor([15.2698, -0.4580,  1.0290], device='cuda:0'),
#   'dim': tensor([1.4157, 0.8537, 1.7809], device='cuda:0'),
#   'distance': 0.09,
#   'cos_sim': tensor(0.9849, device='cuda:0'),
#   'volume': 25.39,
#   'label': 2,
#   'score': 0.18061035871505737,
#   'n_points': 15},
#  {'box': tensor([14.9416, -2.9053,  0.3672], device='cuda:0'),
#   'dim': tensor([4.0944, 1.9235, 1.4996], device='cuda:0'),
#   'distance': 0.07,
#   'cos_sim': tensor(0.9995, device='cuda:0'),
#   'volume': 6.65,
#   'label': 1,
#   'score': 0.12769529223442078,
#   'n_points': 20},
#  {'box': tensor([14.9611, -3.4215,  1.5829], device='cuda:0'),
#   'dim': tensor([1.5708, 1.1484, 1.7820], device='cuda:0'),
#   'distance': 0.03,
#   'cos_sim': tensor(0.9995, device='cuda:0'),
#   'volume': 37.35,
#   'label': 2,
#   'score': 0.18337933719158173,
#   'n_points': 52},
#  {'box': tensor([14.8849, -3.0135, -0.0466], device='cuda:0'),
#   'dim': tensor([4.7881, 2.1435, 1.5978], device='cuda:0'),
#   'distance': 0.11,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.82,
#   'label': 1,
#   'score': 0.7643452286720276,
#   'n_points': 89},
#  {'box': tensor([14.9387, -1.0801,  0.9882], device='cuda:0'),
#   'dim': tensor([2.8161, 1.5659, 1.6395], device='cuda:0'),
#   'distance': 0.39,
#   'cos_sim': tensor(0.9911, device='cuda:0'),
#   'volume': 20.31,
#   'label': 1,
#   'score': 0.18310268223285675,
#   'n_points': 68},
#  {'box': tensor([14.5998, -3.7086,  0.3643], device='cuda:0'),
#   'dim': tensor([0.7179, 0.6848, 1.3433], device='cuda:0'),
#   'distance': 0.23,
#   'cos_sim': tensor(0.9983, device='cuda:0'),
#   'volume': 17.8,
#   'label': 2,
#   'score': 0.1478072702884674,
#   'n_points': 14},
#  {'box': tensor([15.0268, -3.4944,  1.7668], device='cuda:0'),
#   'dim': tensor([1.2676, 1.0418, 2.0498], device='cuda:0'),
#   'distance': 0.13,
#   'cos_sim': tensor(0.9995, device='cuda:0'),
#   'volume': 37.86,
#   'label': 2,
#   'score': 0.34425604343414307,
#   'n_points': 55},
#  {'box': tensor([14.7797, -3.2393,  1.7950], device='cuda:0'),
#   'dim': tensor([4.8766, 2.1560, 2.0243], device='cuda:0'),
#   'distance': 0.15,
#   'cos_sim': tensor(0.9998, device='cuda:0'),
#   'volume': 14.99,
#   'label': 1,
#   'score': 0.1365540623664856,
#   'n_points': 13},
#  {'box': tensor([14.9076, -3.0418,  0.2709], device='cuda:0'),
#   'dim': tensor([4.6751, 2.0715, 1.5482], device='cuda:0'),
#   'distance': 0.08,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 0.58,
#   'label': 1,
#   'score': 0.5020248889923096,
#   'n_points': 75},
#  {'box': tensor([14.6417, -4.6413,  1.5714], device='cuda:0'),
#   'dim': tensor([1.4475, 1.0993, 2.1474], device='cuda:0'),
#   'distance': 0.05,
#   'cos_sim': tensor(0.9940, device='cuda:0'),
#   'volume': 27.23,
#   'label': 2,
#   'score': 0.14198295772075653,
#   'n_points': 41},
#  {'box': tensor([14.9685, -2.8904,  1.5519], device='cuda:0'),
#   'dim': tensor([5.7279, 2.6403, 2.4638], device='cuda:0'),
#   'distance': 0.05,
#   'cos_sim': tensor(1.0000, device='cuda:0'),
#   'volume': 3.3,
#   'label': 1,
#   'score': 0.6422222256660461,
#   'n_points': 62}]

# %%
strong
# Out:
# [0.0,
#  0.0,
#  0.14285714285714285,
#  0.30612244897959184,
#  0.6857142857142857,
#  0.5151515151515151,
#  0.5714285714285714,
#  0.4666666666666667,
#  0.631578947368421,
#  0.6470588235294118]
